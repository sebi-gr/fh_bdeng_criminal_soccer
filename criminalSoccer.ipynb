# %% [markdown]
# # Criminal Soccer
# **Team:** Michael Gangl, Sebastian Grünewald, Patrick Leitner
#
# ## Topic
# The goal of the project is to load and process various datasets from the soccer area and visualize the results. The project is a direct continuation of the Big Data Infrastructure project and to run and analyzed under Data Science aspects.
# For this purpose web scraping, API requests, .csv-File handling, Kafka, Spark and data cleaning is used. Furthermore, the architecture is built in a way that all services and metadata are hosted and is therefore multiuser capable.
#
# ## Question
# With our diagrams we want to analyze if there are correlations between the foul statistics of the players and the crime statistics and/or the gross domestic product (=Bruttoinlandsprodukt) of their countries of origin.
# Additionally, some other interesting and relevant graphs about the datasets will be shown.
#
# ## Architecture <TBD>
# [GitHub](https://github.com/sebi-gr/fh_bdeng_criminal_soccer)
#
# MongoDB: mongodb://pt-n20.p4001.w3.cs.technikum-wien.at:4001</br>
# MongoDB Database: `criminalSoccer`</br>
# MongoDB Collections: `raw_players`, `players`, `countries`, `world_bank_gdp`</br>
#
# Kafka: kafka:9092
# Kafka Topic: `criminal_soccer_gdp
#
# Spark: org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0
# <br>
#
# <img src="imgs/Architekturdiagramm.jpg"/>
#
# ## Spark/Kafka Visualization
# <img src="imgs/Spark_Architektur.jpg"/>

# %% [markdown]
# ## Data Collection
# The following scripts load the data from various sources and stores it into MongoDB
# ### Datasets
# [Kaggle UEFA (.csv-files)](https://www.kaggle.com/datasets/azminetoushikwasi/ucl-202122-uefa-champions-league): This dataset contains all the player stats of UEFA Champions League season 2021-22.
#
# [Wikipedia National Crime Stats](https://en.wikipedia.org/wiki/List_of_countries_by_intentional_homicide_rate): Wikipedia provides a table with crime rates per 100.000 inhabitants.
#
# [World Bank API](http://api.worldbank.org/v2/country/all/indicators/NY.GDP.MKTP.CD?format=json&mrnev=1&per_page=300): Gross Domestic Product from every country in the world (already filtered by non empty most recent values)
#
# [Transfermarkt](https://www.transfermarkt.com/schnellsuche/keinergebnis/schnellsuche?query=): To complete the player stats, we used the Transfermarkt API to search for players by their name.
#
# [Exchange Rates](s://v6.exchangerate-api.com'): Latest exchange rate from USD (because world bank response is in USD) to every currency in the world
#
# ### Technical Notice
# **Make sure Docker is up and running!**
# Due to historical problems with the hosted MongoDB instance from the FH, we implemented a backup strategy with Docker.
#
# ### Steps
# 1. Prepare local backup strategy for mongo with a docker container due to problems with the hosted mongo instance.
# 2. Download UEFA Dataset from kaggle and store the data in MongoDB.
# 3. Call the World Bank API with Kafka and store the responses in a topic. Then with Spark stream it into MognoDB.
# 4. Call the exchange rates API and window stream it with Spark and multiply the result with the field in MongoDB and store it.
# 5. Call the Transfermarkt API and scrape the resulting webpage for additional player infos.
# 6. Scrape Wikipedia to get crime statistics per country and store it in MongoDB.
# 7. Transform the data with proper datatypes and cleanup combined dataset.

# %% [markdown]
# #### Kaggle .csv dataset:
# This dataset contains all the player stats of UEFA Champions League season 2021-22.

# %%
import pandas as pd
import zipfile
import os
import requests

# Importing necessary packages for mongodb connectivity
try:
    from pymongo import MongoClient
    from pymongo.errors import ServerSelectionTimeoutError
except ImportError:
    # !pip install pymongo[srv]
    from pymongo import MongoClient
    from pymongo.errors import ServerSelectionTimeoutError

# Importing config from config.py
from config import MONGO_HOST_REMOTE, MONGO_DB_REMOTE, MONGO_HOST_LOCAL, MONGO_DB_LOCAL

# Defining constants for kaggle files
UEFA_ZIP = "kaggle_players_zip.zip"
UEFA_UNZIPPED = "kaggle_files"
UEFA_FILES = ["key_stats.csv", "disciplinary.csv", "distributon.csv", "defending.csv"] # only some .csv-files are interesting for our purposes
UEFA_RAW_DATA = "raw_players"

# Defining constants for MongoDB connection
conn_str = MONGO_HOST_REMOTE
mongoDB = MONGO_DB_REMOTE

class MongoContext:
    """mongodb client context manager"""
    def __init__(self):
        self.conn_str = MONGO_HOST_REMOTE
        self.mongoDB = MONGO_DB_REMOTE
    def __enter__(self):
        try:
            # print(f"conn_str: {conn_str}  mongoDB: {self.mongoDB}")
            # Connection to Mongo Server from FH-Technikum
            self.client = MongoClient(conn_str)
            self.client.server_info()
            #print("Connection successful to remote mongo host")
            return self.client
        # If connection is not possible, setting a local docker instance
        except ServerSelectionTimeoutError as err:
            print("Remote Error: " + str(err))
            os.system("docker pull mongo")
            os.system("docker run -d -p 27017:27017 mongo:latest")
            self.con_str = MONGO_HOST_LOCAL
            self.mongoDB = MONGO_DB_LOCAL
            try:
                # Trying to connect to the local docker Mongo database
                self.client = MongoClient(conn_str)
                self.client.server_info()
                #print("Connection successful to local mongo host")
                return self.client
            except ServerSelectionTimeoutError as errLocal:
                print("Local Error: " + str(errLocal))

    def __exit__(self, exception_type, exception_value, exception_traceback):
        self.client.close()
        del self.client

def unpack_zip(src, dest):
    """takes files in zip folder from src and extracts them to dest"""
    with zipfile.ZipFile(src, 'r') as zip_ref:
        zip_ref.extractall(dest)

def csv_to_mongo(folder, files, map_key):
    """Fetching data from interesting files in csv folder"""
    # kill existing collection if it exists:
    with MongoContext() as client:
        db = client[mongoDB]
        collection = db[UEFA_RAW_DATA]
        collection.drop()

        for idx, file in enumerate(files):
            df = pd.read_csv(f"{folder}/{file}")
            data = df.to_dict(orient='records')
            if idx == 0:
                # Insert data into mongo
                collection.insert_many(data)
            else:
                for row in data:
                    # Insert data into mongo
                    query = {map_key:  row[map_key]}
                    new_values = {"$set": row}
                    collection.update_one(query, new_values)

def read_from_mongo():
    """reading from mongo database and printing the collection"""
    with MongoContext() as client:
        db = client[mongoDB]
        collection = db[UEFA_RAW_DATA]

        data = collection.find()
        for x in data:
            print("==========================================================================")
            print(x)

def collect_from_kaggle():

    # guard, in case data is already in database.
    with MongoContext() as client:
        db = client[mongoDB]
        if UEFA_RAW_DATA in db.list_collection_names():
            print(f"{UEFA_RAW_DATA} is already in database")
            return False

    unpack_zip(UEFA_ZIP, UEFA_UNZIPPED)
    csv_to_mongo(UEFA_UNZIPPED, UEFA_FILES, "player_name")
    read_from_mongo()

collect_from_kaggle()
# Out:
# raw_players is already in database
# False

# %% [markdown]
# #### WorldBank API with Kafka
# To analyze the players stats against their home origin country and its gross domestic product, we fetch the corresponding data from the World Bank API via a Kafka Consumer.

# %%
import requests
from kafka import KafkaProducer
import json

# Configure Kafka producer
bootstrap_servers = 'kafka:9092'
topic = 'criminal_soccer_gdp'
producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
                         value_serializer=lambda v: json.dumps(v).encode('utf-8'))

# Fetch data from API
api_url = 'http://api.worldbank.org/v2/country/all/indicators/NY.GDP.MKTP.CD?format=json&mrnev=1&per_page=300'
response = requests.get(api_url)
data = response.json()
data = data[1]

# Split data into smaller chunks
chunk_size = 1
chunks = [data[i:i + chunk_size] for i in range(0, len(data), chunk_size)]

# Publish each chunk to Kafka topic
for chunk in chunks:
    producer.send(topic, value=chunk)
    producer.flush()


# Close Kafka producer
producer.close()
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[1], line 8
#       6 bootstrap_servers = 'kafka:9092'
#       7 topic = 'criminal_soccer_gdp'
# ----> 8 producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
#       9                          value_serializer=lambda v: json.dumps(v).encode('utf-8'))
#      11 # Fetch data from API
#      12 api_url = 'http://api.worldbank.org/v2/country/all/indicators/NY.GDP.MKTP.CD?format=json&mrnev=1&per_page=300'
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/kafka/producer/kafka.py:381, in KafkaProducer.__init__(self, **configs)
#     378 reporters = [reporter() for reporter in self.config['metric_reporters']]
#     379 self._metrics = Metrics(metric_config, reporters)
# --> 381 client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     382                      wakeup_timeout_ms=self.config['max_block_ms'],
#     383                      **self.config)
#     385 # Get auto-discovered version from client if necessary
#     386 if self.config['api_version'] is None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/kafka/client_async.py:244, in KafkaClient.__init__(self, **configs)
#     242 if self.config['api_version'] is None:
#     243     check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 244     self.config['api_version'] = self.check_version(timeout=check_timeout)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/kafka/client_async.py:900, in KafkaClient.check_version(self, node_id, timeout, strict)
#     898 if try_node is None:
#     899     self._lock.release()
# --> 900     raise Errors.NoBrokersAvailable()
#     901 self._maybe_connect(try_node)
#     902 conn = self._conns[try_node]
#
# NoBrokersAvailable: NoBrokersAvailable

# %%
# Optional: delete the topic
#from kafka import KafkaAdminClient
#admin_client = KafkaAdminClient(bootstrap_servers=bootstrap_servers)
#admin_client.delete_topics([topic])
# Out:
# DeleteTopicsResponse_v3(throttle_time_ms=0, topic_error_codes=[(topic='criminal_soccer_gdp', error_code=0)])

# %% [markdown]
# #### Spark Data Consumer (Normal Streaming)
# After writing the messages to the Kafka topic we extract those with Spark (using streaming) and save it to our mongo database.

# %%
from pyspark.sql import SparkSession
from config import MONGO_HOST_REMOTE, MONGO_DB_REMOTE, KAFKA_TOPIC, KAFKA_SERVER
from pymongo import MongoClient
import json

# Initialize MongoDB client
mongo_client = MongoClient(MONGO_HOST_REMOTE)
mongo_collection = mongo_client[MONGO_DB_REMOTE]["world_bank_gdp"]

# Define a function to write DataFrame batches to MongoDB
def write_to_mongodb(batch_df, batch_id):
    documents = batch_df.selectExpr("CAST(value AS STRING)").collect()

    for row in documents:
        document = json.loads(row["value"])[0]
        mongo_collection.insert_one(document)


spark = SparkSession.builder.appName("CriminalSoccerStream").config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0").getOrCreate()

df = (spark.readStream                             # readStream indicates streaming
      .format("kafka")                                 # Specify the source format as "kafka"
      .option("kafka.bootstrap.servers", KAFKA_SERVER) # Configure the Kafka server name and port
      .option("subscribe", KAFKA_TOPIC)                # Subscribe to the Kafka topic
      .option("startingOffsets", "earliest")           # Rewind stream to beginning when we restart notebook
      .option("maxOffsetsPerTrigger", 1000)            # Throttle Kafka's processing of the streams
      .load()                                          # Load the DataFrame
      )

df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)") \
    .writeStream \
    .foreachBatch(write_to_mongodb) \
    .start()

spark.streams.awaitAnyTermination()
# Out:
# Overwriting spark-consumer.py

# %% [markdown]
# #### Spark Streaming (Windowing)
# To calculate the GDP into euros we fetch the current exchange rates and window stream it with Spark. The result gets multiplied with the already stored gdp field in MongoDB and stored separately.

# %% [markdown]
# ##### Kafka Producer

# %%
import requests
from kafka import KafkaProducer
import json
import time
from datetime import datetime

# Kafka broker configuration
bootstrap_servers = 'kafka:9092'
topic = 'exchange_rates'

# API configuration
api_key = '232b9314dddc44450ad6db95'
api_url = 'https://v6.exchangerate-api.com/v6/'+api_key+'/latest/USD'

def fetch_api_data():
    try:
        response = requests.get(api_url)
        if response.status_code == 200:
            print(datetime.now().strftime("%d/%m/%Y %H:%M:%S") + ": Fetched Data!")
            return response.json()
        else:
            print(f"Failed to fetch API data. Status code: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while fetching API data: {str(e)}")
        return None

def main():
    # Configure Kafka producer
    producer = KafkaProducer(bootstrap_servers=bootstrap_servers,
                             value_serializer=lambda v: json.dumps(v).encode('utf-8'))

    fetch_interval = 6  # 6s
    num_fetches = 10     # = 1min

    for i in range(num_fetches):
        api_data = fetch_api_data()
        if api_data:
            producer.send(topic, value=api_data)
            producer.flush()
        time.sleep(fetch_interval)

    producer.flush()

if __name__ == '__main__':
    main()

# %% [markdown]
# ##### Spark Streaming Service

# %%
from pyspark.sql import SparkSession

# attention: the .config line is specific for the aida-n2

# Spark session & context
spark = (SparkSession
         .builder
         .appName('exchange-rates-consumer')
         # Add kafka package (so that spark can find kafka for streaming)
         .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0")
         .getOrCreate())
sc = spark.sparkContext

# %%
# Create stream dataframe setting kafka server, topic and offset option
df = (spark
      .readStream
      .format("kafka")
      .option("kafka.bootstrap.servers", "kafka:9092") # kafka server
      .option("subscribe", "exchange_rates") # topic
      .option("startingOffsets", "earliest") # start from beginning
      .load())

# %%
display(df)
# Out:
# DataFrame[key: binary, value: binary, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]

# %%
from pyspark.sql.types import StringType

# Convert binary to string key and value
df1 = (df
       .withColumn("key", df["key"].cast(StringType()))
       .withColumn("value", df["value"].cast(StringType())))

# %%
display(df1)
# Out:
# DataFrame[key: string, value: string, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]

# %%
from pyspark.sql.functions import from_json
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, LongType

schema_exchange_rates = StructType([
    StructField("result", StringType(), True),
    StructField("documentation", StringType(), True),
    StructField("terms_of_use", StringType(), True),
    StructField("time_last_update_unix", LongType(), True),
    StructField("time_last_update_utc", StringType(), True),
    StructField("time_next_update_unix", LongType(), True),
    StructField("time_next_update_utc", StringType(), True),
    StructField("base_code", StringType(), True),
    StructField("conversion_rates", StructType([
        StructField("USD", DoubleType(), True),
        StructField("AED", DoubleType(), True),
        StructField("AFN", DoubleType(), True),
        StructField("ALL", DoubleType(), True),
        StructField("AMD", DoubleType(), True),
        StructField("ANG", DoubleType(), True),
        StructField("AOA", DoubleType(), True),
        StructField("ARS", DoubleType(), True),
        StructField("AUD", DoubleType(), True),
        StructField("AWG", DoubleType(), True),
        StructField("AZN", DoubleType(), True),
        StructField("BAM", DoubleType(), True),
        StructField("BBD", DoubleType(), True),
        StructField("BDT", DoubleType(), True),
        StructField("BGN", DoubleType(), True),
        StructField("BHD", DoubleType(), True),
        StructField("BIF", DoubleType(), True),
        StructField("BMD", DoubleType(), True),
        StructField("BND", DoubleType(), True),
        StructField("BOB", DoubleType(), True),
        StructField("BRL", DoubleType(), True),
        StructField("BSD", DoubleType(), True),
        StructField("BTN", DoubleType(), True),
        StructField("BWP", DoubleType(), True),
        StructField("BYN", DoubleType(), True),
        StructField("BZD", DoubleType(), True),
        StructField("CAD", DoubleType(), True),
        StructField("CDF", DoubleType(), True),
        StructField("CHF", DoubleType(), True),
        StructField("CLP", DoubleType(), True),
        StructField("CNY", DoubleType(), True),
        StructField("COP", DoubleType(), True),
        StructField("CRC", DoubleType(), True),
        StructField("CUP", DoubleType(), True),
        StructField("CVE", DoubleType(), True),
        StructField("CZK", DoubleType(), True),
        StructField("DJF", DoubleType(), True),
        StructField("DKK", DoubleType(), True),
        StructField("DOP", DoubleType(), True),
        StructField("DZD", DoubleType(), True),
        StructField("EGP", DoubleType(), True),
        StructField("ERN", DoubleType(), True),
        StructField("ETB", DoubleType(), True),
        StructField("EUR", DoubleType(), True),
        StructField("FJD", DoubleType(), True),
        StructField("FKP", DoubleType(), True),
        StructField("FOK", DoubleType(), True),
        StructField("GBP", DoubleType(), True),
        StructField("GEL", DoubleType(), True),
        StructField("GGP", DoubleType(), True),
        StructField("GHS", DoubleType(), True),
        StructField("GIP", DoubleType(), True),
        StructField("GMD", DoubleType(), True),
        StructField("GNF", DoubleType(), True),
        StructField("GTQ", DoubleType(), True),
        StructField("GYD", DoubleType(), True),
        StructField("HKD", DoubleType(), True),
        StructField("HNL", DoubleType(), True),
        StructField("HRK", DoubleType(), True),
        StructField("HTG", DoubleType(), True),
        StructField("HUF", DoubleType(), True),
        StructField("IDR", DoubleType(), True),
        StructField("ILS", DoubleType(), True),
        StructField("IMP", DoubleType(), True),
        StructField("INR", DoubleType(), True),
        StructField("IQD", DoubleType(), True),
        StructField("IRR", DoubleType(), True),
        StructField("ISK", DoubleType(), True),
        StructField("JEP", DoubleType(), True),
        StructField("JMD", DoubleType(), True),
        StructField("JOD", DoubleType(), True),
        StructField("JPY", DoubleType(), True),
        StructField("KES", DoubleType(), True),
        StructField("KGS", DoubleType(), True),
        StructField("KHR", DoubleType(), True),
        StructField("KID", DoubleType(), True),
        StructField("KMF", DoubleType(), True),
        StructField("KRW", DoubleType(), True),
        StructField("KWD", DoubleType(), True),
        StructField("KYD", DoubleType(), True),
        StructField("KZT", DoubleType(), True),
        StructField("LAK", DoubleType(), True),
        StructField("LBP", DoubleType(), True),
        StructField("LKR", DoubleType(), True),
        StructField("LRD", DoubleType(), True),
        StructField("LSL", DoubleType(), True),
        StructField("LYD", DoubleType(), True),
        StructField("MAD", DoubleType(), True),
        StructField("MDL", DoubleType(), True),
        StructField("MGA", DoubleType(), True),
        StructField("MKD", DoubleType(), True),
        StructField("MMK", DoubleType(), True),
        StructField("MNT", DoubleType(), True),
        StructField("MOP", DoubleType(), True),
        StructField("MRU", DoubleType(), True),
        StructField("MUR", DoubleType(), True),
        StructField("MVR", DoubleType(), True),
        StructField("MWK", DoubleType(), True),
        StructField("MXN", DoubleType(), True),
        StructField("MYR", DoubleType(), True),
        StructField("MZN", DoubleType(), True),
        StructField("NAD", DoubleType(), True),
        StructField("NGN", DoubleType(), True),
        StructField("NIO", DoubleType(), True),
        StructField("NOK", DoubleType(), True),
        StructField("NPR", DoubleType(), True),
        StructField("NZD", DoubleType(), True),
        StructField("OMR", DoubleType(), True),
        StructField("PAB", DoubleType(), True),
        StructField("PEN", DoubleType(), True),
        StructField("PGK", DoubleType(), True),
        StructField("PHP", DoubleType(), True),
        StructField("PKR", DoubleType(), True),
        StructField("PLN", DoubleType(), True),
        StructField("PYG", DoubleType(), True),
        StructField("QAR", DoubleType(), True),
        StructField("RON", DoubleType(), True),
        StructField("RSD", DoubleType(), True),
        StructField("RUB", DoubleType(), True),
        StructField("RWF", DoubleType(), True),
        StructField("SAR", DoubleType(), True),
        StructField("SBD", DoubleType(), True),
        StructField("SCR", DoubleType(), True),
        StructField("SDG", DoubleType(), True),
        StructField("SEK", DoubleType(), True),
        StructField("SGD", DoubleType(), True),
        StructField("SHP", DoubleType(), True),
        StructField("SLE", DoubleType(), True),
        StructField("SLL", DoubleType(), True),
        StructField("SOS", DoubleType(), True),
        StructField("SRD", DoubleType(), True),
        StructField("SSP", DoubleType(), True),
        StructField("STN", DoubleType(), True),
        StructField("SYP", DoubleType(), True),
        StructField("SZL", DoubleType(), True),
        StructField("THB", DoubleType(), True),
        StructField("TJS", DoubleType(), True),
        StructField("TMT", DoubleType(), True),
        StructField("TND", DoubleType(), True),
        StructField("TOP", DoubleType(), True),
        StructField("TRY", DoubleType(), True),
        StructField("TTD", DoubleType(), True),
        StructField("TVD", DoubleType(), True),
        StructField("TWD", DoubleType(), True),
        StructField("TZS", DoubleType(), True),
        StructField("UAH", DoubleType(), True),
        StructField("UGX", DoubleType(), True),
        StructField("UYU", DoubleType(), True),
        StructField("UZS", DoubleType(), True),
        StructField("VES", DoubleType(), True),
        StructField("VND", DoubleType(), True),
        StructField("VUV", DoubleType(), True),
        StructField("WST", DoubleType(), True),
        StructField("XAF", DoubleType(), True),
        StructField("XCD", DoubleType(), True),
        StructField("XDR", DoubleType(), True),
        StructField("XOF", DoubleType(), True),
        StructField("XPF", DoubleType(), True),
        StructField("YER", DoubleType(), True),
        StructField("ZAR", DoubleType(), True),
        StructField("ZMW", DoubleType(), True),
        StructField("ZWL", DoubleType(), True)]))])

# Create dataframe setting schema for event data
df_exchange_rates = (df1
                     # Sets schema for event data
                     .withColumn("value", from_json("value", schema_exchange_rates))
                     )

# %%
display(df_exchange_rates)
# Out:
# DataFrame[key: string, value: struct<result:string,documentation:string,terms_of_use:string,time_last_update_unix:bigint,time_last_update_utc:string,time_next_update_unix:bigint,time_next_update_utc:string,base_code:string,conversion_rates:struct<USD:double,AED:double,AFN:double,ALL:double,AMD:double,ANG:double,AOA:double,ARS:double,AUD:double,AWG:double,AZN:double,BAM:double,BBD:double,BDT:double,BGN:double,BHD:double,BIF:double,BMD:double,BND:double,BOB:double,BRL:double,BSD:double,BTN:double,BWP:double,BYN:double,BZD:double,CAD:double,CDF:double,CHF:double,CLP:double,CNY:double,COP:double,CRC:double,CUP:double,CVE:double,CZK:double,DJF:double,DKK:double,DOP:double,DZD:double,EGP:double,ERN:double,ETB:double,EUR:double,FJD:double,FKP:double,FOK:double,GBP:double,GEL:double,GGP:double,GHS:double,GIP:double,GMD:double,GNF:double,GTQ:double,GYD:double,HKD:double,HNL:double,HRK:double,HTG:double,HUF:double,IDR:double,ILS:double,IMP:double,INR:double,IQD:double,IRR:double,ISK:double,JEP:double,JMD:double,JOD:double,JPY:double,KES:double,KGS:double,KHR:double,KID:double,KMF:double,KRW:double,KWD:double,KYD:double,KZT:double,LAK:double,LBP:double,LKR:double,LRD:double,LSL:double,LYD:double,MAD:double,MDL:double,MGA:double,MKD:double,MMK:double,MNT:double,MOP:double,MRU:double,MUR:double,MVR:double,MWK:double,MXN:double,MYR:double,MZN:double,NAD:double,NGN:double,NIO:double,NOK:double,NPR:double,NZD:double,OMR:double,PAB:double,PEN:double,PGK:double,PHP:double,PKR:double,PLN:double,PYG:double,QAR:double,RON:double,RSD:double,RUB:double,RWF:double,SAR:double,SBD:double,SCR:double,SDG:double,SEK:double,SGD:double,SHP:double,SLE:double,SLL:double,SOS:double,SRD:double,SSP:double,STN:double,SYP:double,SZL:double,THB:double,TJS:double,TMT:double,TND:double,TOP:double,TRY:double,TTD:double,TVD:double,TWD:double,TZS:double,UAH:double,UGX:double,UYU:double,UZS:double,VES:double,VND:double,VUV:double,WST:double,XAF:double,XCD:double,XDR:double,XOF:double,XPF:double,YER:double,ZAR:double,ZMW:double,ZWL:double>>, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]

# %%
windowDuration = "5 seconds"  # Window duration for aggregating data
slideDuration = "2 seconds"   # Sliding interval for window

# %%
from pyspark.sql.functions import window, avg
import pandas as pd
from config import MONGO_HOST_REMOTE, MONGO_DB_REMOTE, KAFKA_TOPIC, KAFKA_SERVER
from pymongo import MongoClient

# Initialize MongoDB client
mongo_client = MongoClient(MONGO_HOST_REMOTE)
mongo_collection = mongo_client[MONGO_DB_REMOTE]["world_bank_gdp"]

try:
    # Apply window function on the timestamp column with the specified window duration and sliding interval
    windowed_df = df_exchange_rates.withColumn("window", window("timestamp", windowDuration, slideDuration))

    # Perform aggregation within the window by calculating the average exchange rate for each currency
    aggregated_df = windowed_df.groupBy("window").agg(avg("value.conversion_rates.EUR").alias("average_exchange_rate_EUR"))

    def add_to_mongo(batch_df, batch_id):
        # Retrieve the documents from the collection
        documents = mongo_collection.find()

        # Iterate over each document
        for document in documents:
            # Get the value of the existing field
            existing_value = document["value"]
            
            val = batch_df.select("average_exchange_rate_EUR").first()

            average_exchange_rate_eur = val["average_exchange_rate_EUR"]

            # Calculate the new value
            gdp_eur = existing_value * average_exchange_rate_eur

            # Update the document with the new field and value
            mongo_collection.update_one(
                {"_id": document["_id"]},
                {"$set": {"gdp_eur": gdp_eur}}
            )

        # Close the MongoDB connection
        client.close()


    # Start the streaming query to process the data
    query = (aggregated_df
             .writeStream
             .outputMode("update")  # Use Update mode for aggregation
             .foreachBatch(add_to_mongo)  # Call the add_to_mongo function for each batch
             .option("checkpointLocation", "checkpoints")  # Specify the checkpoint directory path
             .start())

    # Wait for the streaming query to finish processing the data
    query.awaitTermination()

except KeyboardInterrupt:
    print("Process terminated")
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/opt/conda/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Process terminated

# %% [markdown]
# #### Transfermarkt API and Crawler
# <img src="imgs/Transfermarkt_logo.png" style="width:200px; height:auto"/>
#
# In Order to collect insights on players nationality we are querying the Transfermarkt [website](https://transfermarkt.com). We then parse the html response to collect `full_name`, `nationality`, `icon` and `market_value` from it.

# %%
try:
    import parsel
except ImportError:
    # !pip install parsel
    import parsel


def transfermarkt_spider(name):
    """queries transfermarkt.com and parses response table"""
    ua = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"
    header = {"user-agent": ua}
    result = None
    with requests.Session() as session:
        url = "https://www.transfermarkt.com/schnellsuche/ergebnis/schnellsuche"
        req = session.get(url, params={"query": name}, headers=header) # API call
        response = parsel.Selector(req.text)
        try:
            # retrieve data from table
            row = response.xpath("//table[@class='items']/tbody/tr[1]")
            icon_url = row.xpath(".//table//img/@src").get()
            name = row.xpath(".//table//img/@title").get()
            national = row.xpath("./td[5]/img[1]/@alt").get()
            value = row.xpath("./td[6]/text()").get()
            result = dict(icon=icon_url, full_name=name, nationality=national, market_value=value)
        except:
            pass
    return result

# Collect from Transfermarkt.com
with MongoContext() as client:
    # MongoDB connection
    db = client[mongoDB]
    collection = db[UEFA_RAW_DATA]
    raw = collection.find()
    count = 0

    # add the complementary data to the mongo documents
    mongo_rows = collection.find({ "nationality": { "$exists":False }})
    for mongo_player in mongo_rows:
        print(mongo_player["player_name"])
        if not mongo_player.get("nationality"):
            name = mongo_player["player_name"]
            transfer_data = transfermarkt_spider(name)
            if transfer_data:
                print(transfer_data)
                collection.update_one({"player_name": name}, {"$set": transfer_data})
# Out:
# Courtois
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/108390-1665067957.jpg?lm=1', 'full_name': 'Thibaut Courtois', 'nationality': 'Belgium', 'market_value': '€45.00m'}
# Vinícius Júnior
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/371998-1664869583.jpg?lm=1', 'full_name': 'Vinicius Junior', 'nationality': 'Brazil', 'market_value': '€150.00m'}
# Benzema
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/18922-1653042225.jpg?lm=1', 'full_name': 'Karim Benzema', 'nationality': 'France', 'market_value': '€25.00m'}
# Modrić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/27992-1661426133.jpg?lm=1', 'full_name': 'Luka Modric', 'nationality': 'Croatia', 'market_value': '€10.00m'}
# Éder Militão
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/401530-1568189259.jpg?lm=1', 'full_name': 'Éder Militão', 'nationality': 'Brazil', 'market_value': '€70.00m'}
# Alaba
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/59016-1684921582.jpeg?lm=1', 'full_name': 'David Alaba', 'nationality': 'Austria', 'market_value': '€40.00m'}
# Carvajal
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/138927-1684232714.jpeg?lm=1', 'full_name': 'Daniel Carvajal', 'nationality': 'Spain', 'market_value': '€12.00m'}
# Casemiro
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/16306-1661426172.jpg?lm=1', 'full_name': 'Casemiro', 'nationality': 'Brazil', 'market_value': '€50.00m'}
# Kroos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/31909-1661426083.jpg?lm=1', 'full_name': 'Toni Kroos', 'nationality': 'Germany', 'market_value': '€15.00m'}
# Mendy
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/157495-1598301159.jpg?lm=1', 'full_name': 'Benjamin Mendy', 'nationality': 'France', 'market_value': '-'}
# Valverde
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/369081-1681999815.jpg?lm=1', 'full_name': 'Federico Valverde', 'nationality': 'Uruguay', 'market_value': '€100.00m'}
# Nacho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/58884-1664964956.jpg?lm=1', 'full_name': 'Nacho Fernández', 'nationality': 'Spain', 'market_value': '€6.00m'}
# Rodrygo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/412363-1653297541.jpg?lm=1', 'full_name': 'Rodrygo', 'nationality': 'Brazil', 'market_value': '€100.00m'}
# Lucas Vázquez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/221316-1536655786.jpg?lm=1', 'full_name': 'Lucas Vázquez', 'nationality': 'Spain', 'market_value': '€8.00m'}
# Camavinga
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/640428-1668500874.jpg?lm=1', 'full_name': 'Eduardo Camavinga', 'nationality': 'France', 'market_value': '€85.00m'}
# Asensio
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/296622-1664970818.jpg?lm=1', 'full_name': 'Marco Asensio', 'nationality': 'Spain', 'market_value': '€25.00m'}
# Jović
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/257462-1657519856.jpg?lm=1', 'full_name': 'Luka Jovic', 'nationality': 'Serbia', 'market_value': '€8.00m'}
# Marcelo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/44501-1603112392.jpg?lm=1', 'full_name': 'Marcelo', 'nationality': 'Brazil', 'market_value': '€2.00m'}
# E. Hazard
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Miguel Gutiérrez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/525299-1576537307.jpeg?lm=1', 'full_name': 'Miguel Gutiérrez', 'nationality': 'Spain', 'market_value': '€10.00m'}
# Ceballos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/319745-1561391851.jpg?lm=1', 'full_name': 'Dani Ceballos', 'nationality': 'Spain', 'market_value': '€12.00m'}
# Mariano Díaz
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/225020-1684487196.jpg?lm=1', 'full_name': 'Mariano Díaz', 'nationality': 'Dominican Republic', 'market_value': '€2.50m'}
# Vallejo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/251896-1684241186.jpg?lm=1', 'full_name': 'Jesús Vallejo', 'nationality': 'Spain', 'market_value': '€2.00m'}
# Bale
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/39381-1658665343.jpg?lm=1', 'full_name': 'Gareth Bale', 'nationality': 'Wales', 'market_value': '-'}
# Blanco
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/7349-1570439548.jpg?lm=1', 'full_name': 'Raúl', 'nationality': 'Spain', 'market_value': '-'}
# Alisson Becker
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/105470-1668522221.jpg?lm=1', 'full_name': 'Alisson', 'nationality': 'Brazil', 'market_value': '€45.00m'}
# Salah
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/148455-1546611604.jpg?lm=1', 'full_name': 'Mohamed Salah', 'nationality': 'Egypt', 'market_value': '€70.00m'}
# Fabinho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/225693-1580133493.jpg?lm=1', 'full_name': 'Fabinho', 'nationality': 'Brazil', 'market_value': '€45.00m'}
# Robertson
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/234803-1662621166.jpg?lm=1', 'full_name': 'Andrew Robertson', 'nationality': 'Scotland', 'market_value': '€48.00m'}
# Mané
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/200512-1667830279.jpg?lm=1', 'full_name': 'Sadio Mané', 'nationality': 'Senegal', 'market_value': '€45.00m'}
# Van Dijk
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/139208-1620651710.jpg?lm=1', 'full_name': 'Virgil van Dijk', 'nationality': 'Netherlands', 'market_value': '€45.00m'}
# Alexander-Arnold
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/314353-1662621037.jpg?lm=1', 'full_name': 'Trent Alexander-Arnold', 'nationality': 'England', 'market_value': '€65.00m'}
# Konaté
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/357119-1669190550.jpg?lm=1', 'full_name': 'Ibrahima Konaté', 'nationality': 'France', 'market_value': '€35.00m'}
# Henderson
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/61651-1662621084.jpg?lm=1', 'full_name': 'Jordan Henderson', 'nationality': 'England', 'market_value': '€10.00m'}
# Matip
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/82105-1544635015.jpg?lm=1', 'full_name': 'Joel Matip', 'nationality': 'Cameroon', 'market_value': '€16.00m'}
# Thiago Alcántara
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/60444-1540568423.jpg?lm=1', 'full_name': 'Thiago', 'nationality': 'Spain', 'market_value': '€18.00m'}
# Diogo Jota
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/340950-1633340107.jpg?lm=1', 'full_name': 'Diogo Jota', 'nationality': 'Portugal', 'market_value': '€55.00m'}
# Keïta
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/302215-1503302375.jpg?lm=1', 'full_name': 'Naby Keïta', 'nationality': 'Guinea', 'market_value': '€17.00m'}
# Luis Díaz
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/480692-1665556242.jpg?lm=1', 'full_name': 'Luis Díaz', 'nationality': 'Colombia', 'market_value': '€75.00m'}
# Tsimikas
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/338070-1682088468.jpg?lm=1', 'full_name': 'Konstantinos Tsimikas', 'nationality': 'Greece', 'market_value': '€18.00m'}
# Firmino
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/131789-1520605270.jpg?lm=1', 'full_name': 'Roberto Firmino', 'nationality': 'Brazil', 'market_value': '€22.00m'}
# Oxlade-Chamberlain
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/143424-1471253943.jpg?lm=1', 'full_name': 'Alex Oxlade-Chamberlain', 'nationality': 'England', 'market_value': '€10.00m'}
# Gomez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/48280-1619791055.jpg?lm=1', 'full_name': 'Edinson Cavani', 'nationality': 'Uruguay', 'market_value': '€3.00m'}
# Minamino
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/165793-1565700962.jpg?lm=1', 'full_name': 'Takumi Minamino', 'nationality': 'Japan', 'market_value': '€8.00m'}
# Milner
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/3333-1662621121.jpg?lm=1', 'full_name': 'James Milner', 'nationality': 'England', 'market_value': '€2.00m'}
# Origi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/148368-1661510925.jpg?lm=1', 'full_name': 'Divock Origi', 'nationality': 'Belgium', 'market_value': '€6.00m'}
# Jones
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/433188-1682088950.jpg?lm=1', 'full_name': 'Curtis Jones', 'nationality': 'England', 'market_value': '€17.00m'}
# N. Williams
# {'icon': 'https://tmssl.akamaized.net/images/berater_logo/small/berater-default.png?lm=1520606995', 'full_name': 'CAA Base Ltd', 'nationality': None, 'market_value': None}
# Morton
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/618494-1637834244.jpg?lm=1', 'full_name': 'Tyler Morton', 'nationality': 'England', 'market_value': '€7.00m'}
# Phillips
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/351749-1661978510.jpg?lm=1', 'full_name': 'Kalvin Phillips', 'nationality': 'England', 'market_value': '€35.00m'}
# Elliott
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/565822-1665128076.jpg?lm=1', 'full_name': 'Harvey Elliott', 'nationality': 'England', 'market_value': '€35.00m'}
# Woltman
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1', 'full_name': 'Jörg Woltmann', 'nationality': 'Germany', 'market_value': '-'}
# Bradley
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/258919-1580389388.jpg?lm=1', 'full_name': 'Dean Henderson', 'nationality': 'England', 'market_value': '€22.00m'}
# Pau Torres
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/399776-1568023168.jpg?lm=1', 'full_name': 'Pau Torres', 'nationality': 'Spain', 'market_value': '€45.00m'}
# Rulli
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/229604-1665059858.jpg?lm=1', 'full_name': 'Gerónimo Rulli', 'nationality': 'Argentina', 'market_value': '€10.00m'}
# Parejo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/59561-1447247408.jpg?lm=1', 'full_name': 'Dani Parejo', 'nationality': 'Spain', 'market_value': '€6.00m'}
# Capoue
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/63494-1455120745.jpg?lm=1', 'full_name': 'Étienne Capoue', 'nationality': 'France', 'market_value': '€3.00m'}
# Albiol
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/15452-1664974689.jpg?lm=1', 'full_name': 'Raúl Albiol', 'nationality': 'Spain', 'market_value': '€2.50m'}
# Ederson
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/238223-1661978747.jpg?lm=1', 'full_name': 'Ederson', 'nationality': 'Brazil', 'market_value': '€45.00m'}
# Mahrez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/171424-1683630060.jpg?lm=1', 'full_name': 'Riyad Mahrez', 'nationality': 'Algeria', 'market_value': '€30.00m'}
# Danjuma
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/355861-1674657323.jpg?lm=1', 'full_name': 'Arnaut Danjuma', 'nationality': 'Netherlands', 'market_value': '€27.00m'}
# Vertonghen
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/43250-1668080180.jpg?lm=1', 'full_name': 'Jan Vertonghen', 'nationality': 'Belgium', 'market_value': '€1.50m'}
# Vlachodimos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/124419-1603794112.jpg?lm=1', 'full_name': 'Odysseas Vlachodimos', 'nationality': 'Greece', 'market_value': '€16.00m'}
# Oblak
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/121483-1599986864.jpg?lm=1', 'full_name': 'Jan Oblak', 'nationality': 'Slovenia', 'market_value': '€35.00m'}
# Foyth
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/480763-1662668281.jpg?lm=1', 'full_name': 'Juan Foyth', 'nationality': 'Argentina', 'market_value': '€25.00m'}
# Bernardo Silva
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/241641-1684311533.jpg?lm=1', 'full_name': 'Bernardo Silva', 'nationality': 'Portugal', 'market_value': '€80.00m'}
# Lewandowski
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/38253-1642434304.jpg?lm=1', 'full_name': 'Robert Lewandowski', 'nationality': 'Poland', 'market_value': '€30.00m'}
# Grimaldo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/193082-1684143200.jpg?lm=1', 'full_name': 'Alejandro Grimaldo', 'nationality': 'Spain', 'market_value': '€25.00m'}
# Rodri
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/88103-1540568385.jpg?lm=1', 'full_name': 'James Rodríguez', 'nationality': 'Colombia', 'market_value': '€6.00m'}
# João Cancelo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/182712-1675080937.jpg?lm=1', 'full_name': 'João Cancelo', 'nationality': 'Portugal', 'market_value': '€60.00m'}
# Rüdiger
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/86202-1684484602.jpg?lm=1', 'full_name': 'Antonio Rüdiger', 'nationality': 'Germany', 'market_value': '€32.00m'}
# Mendy
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/157495-1598301159.jpg?lm=1', 'full_name': 'Benjamin Mendy', 'nationality': 'France', 'market_value': '-'}
# Reinildo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/240692-1666818500.jpg?lm=1', 'full_name': 'Reinildo Mandava', 'nationality': 'Mozambique', 'market_value': '€25.00m'}
# Neuer
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/17259-1667830554.jpg?lm=1', 'full_name': 'Manuel Neuer', 'nationality': 'Germany', 'market_value': '€7.00m'}
# Weigl
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/196792-1662965628.jpg?lm=1', 'full_name': 'Julian Weigl', 'nationality': 'Germany', 'market_value': '€15.00m'}
# Otamendi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/54781-1669835534.jpg?lm=1', 'full_name': 'Nicolás Otamendi', 'nationality': 'Argentina', 'market_value': '€2.00m'}
# Sané
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/192565-1655064190.jpg?lm=1', 'full_name': 'Leroy Sané', 'nationality': 'Germany', 'market_value': '€70.00m'}
# Laporte
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/176553-1685546335.jpg?lm=1', 'full_name': 'Aymeric Laporte', 'nationality': 'Spain', 'market_value': '€30.00m'}
# Müller
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/58358-1667830486.jpg?lm=1', 'full_name': 'Thomas Müller', 'nationality': 'Germany', 'market_value': '€18.00m'}
# Pavard
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/353366-1667831086.jpg?lm=1', 'full_name': 'Benjamin Pavard', 'nationality': 'France', 'market_value': '€35.00m'}
# Thiago Silva
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/29241-1661856081.jpg?lm=1', 'full_name': 'Thiago Silva', 'nationality': 'Brazil', 'market_value': '€2.50m'}
# De Bruyne
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/88755-1684245748.jpg?lm=1', 'full_name': 'Kevin De Bruyne', 'nationality': 'Belgium', 'market_value': '€80.00m'}
# Škriniar
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/204069-1598256813.jpg?lm=1', 'full_name': 'Milan Skriniar', 'nationality': 'Slovakia', 'market_value': '€50.00m'}
# Kristensen
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/369684-1601103298.png?lm=1', 'full_name': 'Rasmus Kristensen', 'nationality': 'Denmark', 'market_value': '€15.00m'}
# Martínez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/44017-1540568493.jpg?lm=1', 'full_name': 'Javi Martínez', 'nationality': 'Spain', 'market_value': '€1.80m'}
# Marquinhos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/181767-1672303747.jpg?lm=1', 'full_name': 'Marquinhos', 'nationality': 'Brazil', 'market_value': '€70.00m'}
# Fonte
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/33829-1666690457.jpg?lm=1', 'full_name': 'José Fonte', 'nationality': 'Portugal', 'market_value': '€700k'}
# Köhn
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/13769-1479802524.jpg?lm=1', 'full_name': 'Stefan Kohn', 'nationality': 'Germany', 'market_value': '-'}
# Handanovič
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/28021-1686929975.jpg?lm=1', 'full_name': 'Samir Handanovic', 'nationality': 'Slovenia', 'market_value': '€500k'}
# Hakimi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/398073-1672304327.jpg?lm=1', 'full_name': 'Achraf Hakimi', 'nationality': 'Morocco', 'market_value': '€70.00m'}
# Ulmer
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/31196-1661532297.png?lm=1', 'full_name': 'Andreas Ulmer', 'nationality': 'Austria', 'market_value': '€400k'}
# Gilberto
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/3194-1683295254.jpg?lm=1', 'full_name': 'Gilberto Silva', 'nationality': 'Brazil', 'market_value': '-'}
# Aaronson
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/393323-1583780617.JPG?lm=1', 'full_name': 'Brenden Aaronson', 'nationality': 'United States', 'market_value': '€30.00m'}
# Rafa Silva
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/238055-1603795640.jpg?lm=1', 'full_name': 'Rafa', 'nationality': 'Portugal', 'market_value': '€22.00m'}
# Gravenberch
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/478573-1661804381.jpg?lm=1', 'full_name': 'Ryan Gravenberch', 'nationality': 'Netherlands', 'market_value': '€30.00m'}
# Kimmich
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/161056-1667829955.jpg?lm=1', 'full_name': 'Joshua Kimmich', 'nationality': 'Germany', 'market_value': '€80.00m'}
# Marcos Llorente
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/282411-1684159821.jpg?lm=1', 'full_name': 'Marcos Llorente', 'nationality': 'Spain', 'market_value': '€35.00m'}
# Azpilicueta
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/57500-1668169250.jpg?lm=1', 'full_name': 'César Azpilicueta', 'nationality': 'Spain', 'market_value': '€8.00m'}
# David
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/59016-1684921582.jpeg?lm=1', 'full_name': 'David Alaba', 'nationality': 'Austria', 'market_value': '€40.00m'}
# Mbappé
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/342229-1682683695.jpg?lm=1', 'full_name': 'Kylian Mbappé', 'nationality': 'France', 'market_value': '€180.00m'}
# Havertz
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/309400-1683903902.jpg?lm=1', 'full_name': 'Kai Havertz', 'nationality': 'Germany', 'market_value': '€60.00m'}
# Camara
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/543382-1601103576.png?lm=1', 'full_name': 'Mohamed Camara', 'nationality': 'Mali', 'market_value': '€28.00m'}
# Haller
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/181375-1661412873.jpg?lm=1', 'full_name': 'Sébastien Haller', 'nationality': "Cote d'Ivoire", 'market_value': '€30.00m'}
# Bastoni
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/315853-1630304611.jpg?lm=1', 'full_name': 'Alessandro Bastoni', 'nationality': 'Italy', 'market_value': '€60.00m'}
# Koke
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/74229-1664970397.jpg?lm=1', 'full_name': 'Koke', 'nationality': 'Spain', 'market_value': '€16.00m'}
# Rúben Dias
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/258004-1684921271.jpg?lm=1', 'full_name': 'Rúben Dias', 'nationality': 'Portugal', 'market_value': '€75.00m'}
# Mazraoui
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/340456-1667830761.jpg?lm=1', 'full_name': 'Noussair Mazraoui', 'nationality': 'Morocco', 'market_value': '€28.00m'}
# Gündoğan
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/53622-1666733465.jpg?lm=1', 'full_name': 'Ilkay Gündogan', 'nationality': 'Germany', 'market_value': '€25.00m'}
# Upamecano
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/344695-1667829882.jpg?lm=1', 'full_name': 'Dayot Upamecano', 'nationality': 'France', 'market_value': '€60.00m'}
# Foden
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/406635-1668524492.jpg?lm=1', 'full_name': 'Phil Foden', 'nationality': 'England', 'market_value': '€110.00m'}
# Seiwald
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/404950-1661531848.png?lm=1', 'full_name': 'Nicolas Seiwald', 'nationality': 'Austria', 'market_value': '€20.00m'}
# Estupiñán
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/349599-1668498118.jpg?lm=1', 'full_name': 'Pervis Estupiñán', 'nationality': 'Ecuador', 'market_value': '€20.00m'}
# Stones
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/186590-1684764261.jpg?lm=1', 'full_name': 'John Stones', 'nationality': 'England', 'market_value': '€30.00m'}
# Brozović
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/156617-1661352678.jpg?lm=1', 'full_name': 'Marcelo Brozovic', 'nationality': 'Croatia', 'market_value': '€25.00m'}
# Coman
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/243714-1667830093.jpg?lm=1', 'full_name': 'Kingsley Coman', 'nationality': 'France', 'market_value': '€65.00m'}
# Messi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/28003-1671435885.jpg?lm=1', 'full_name': 'Lionel Messi', 'nationality': 'Argentina', 'market_value': '€45.00m'}
# Tadić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/36139-1661978004.jpg?lm=1', 'full_name': 'Dusan Tadic', 'nationality': 'Serbia', 'market_value': '€7.00m'}
# André
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/7600-1685447666.jpg?lm=1', 'full_name': 'Andrés Iniesta', 'nationality': 'Spain', 'market_value': '€1.20m'}
# Kimpembe
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/282041-1672304083.jpg?lm=1', 'full_name': 'Presnel Kimpembe', 'nationality': 'France', 'market_value': '€35.00m'}
# Adán
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/44062-1602774525.jpg?lm=1', 'full_name': 'Antonio Adán', 'nationality': 'Spain', 'market_value': '€1.00m'}
# Szczęsny
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/44058-1595847517.jpg?lm=1', 'full_name': 'Wojciech Szczesny', 'nationality': 'Poland', 'market_value': '€10.00m'}
# De Gea
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/59377-1667548362.jpg?lm=1', 'full_name': 'David de Gea', 'nationality': 'Spain', 'market_value': '€15.00m'}
# Berghuis
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/129554-1668696215.jpg?lm=1', 'full_name': 'Steven Berghuis', 'nationality': 'Netherlands', 'market_value': '€14.00m'}
# De Ligt
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/326031-1667829815.jpg?lm=1', 'full_name': 'Matthijs de Ligt', 'nationality': 'Netherlands', 'market_value': '€75.00m'}
# Núñez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/546543-1681827179.jpg?lm=1', 'full_name': 'Darwin Núñez', 'nationality': 'Uruguay', 'market_value': '€70.00m'}
# Matheus Reis
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/379249-1666100890.jpg?lm=1', 'full_name': 'Matheus Reis', 'nationality': 'Brazil', 'market_value': '€8.00m'}
# Ronaldo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/8198-1685035469.png?lm=1', 'full_name': 'Cristiano Ronaldo', 'nationality': 'Portugal', 'market_value': '€15.00m'}
# Adeyemi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/496094-1661413548.jpg?lm=1', 'full_name': 'Karim Adeyemi', 'nationality': 'Germany', 'market_value': '€35.00m'}
# Christensen
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/196948-1668183241.jpg?lm=1', 'full_name': 'Andreas Christensen', 'nationality': 'Denmark', 'market_value': '€40.00m'}
# Zeki Çelik
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/251075-1641464889.jpg?lm=1', 'full_name': 'Zeki Celik', 'nationality': 'Turkey', 'market_value': '€10.00m'}
# Martínez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/44017-1540568493.jpg?lm=1', 'full_name': 'Javi Martínez', 'nationality': 'Spain', 'market_value': '€1.80m'}
# Giménez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/250845-1664970029.jpg?lm=1', 'full_name': 'José María Giménez', 'nationality': 'Uruguay', 'market_value': '€35.00m'}
# Paulinho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/57229-1563350348.jpg?lm=1', 'full_name': 'Paulinho', 'nationality': 'Brazil', 'market_value': '€1.20m'}
# Sterling
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/134425-1684165974.jpg?lm=1', 'full_name': 'Raheem Sterling', 'nationality': 'England', 'market_value': '€60.00m'}
# Nuno Mendes
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/616341-1672304855.jpg?lm=1', 'full_name': 'Nuno Mendes', 'nationality': 'Portugal', 'market_value': '€65.00m'}
# Bonucci
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/39983-1661268218.jpg?lm=1', 'full_name': 'Leonardo Bonucci', 'nationality': 'Italy', 'market_value': '€1.50m'}
# Kondogbia
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/127189-1664975185.jpg?lm=1', 'full_name': 'Geoffrey Kondogbia', 'nationality': 'Central African Republic', 'market_value': '€14.00m'}
# De Paul
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/191614-1645609861.jpg?lm=1', 'full_name': 'Fred', 'nationality': 'Brazil', 'market_value': '€20.00m'}
# Antony
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/602105-1680698738.jpg?lm=1', 'full_name': 'Antony', 'nationality': 'Brazil', 'market_value': '€70.00m'}
# Walker
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/95424-1668090663.jpg?lm=1', 'full_name': 'Kyle Walker', 'nationality': 'England', 'market_value': '€15.00m'}
# João Félix
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/462250-1668165358.jpg?lm=1', 'full_name': 'João Félix', 'nationality': 'Portugal', 'market_value': '€50.00m'}
# Wöber
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/263361-1661532387.png?lm=1', 'full_name': 'Maximilian Wöber', 'nationality': 'Austria', 'market_value': '€12.00m'}
# Blind
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/12282-1660761781.jpg?lm=1', 'full_name': 'Daley Blind', 'nationality': 'Netherlands', 'market_value': '€6.00m'}
# L. Hernández
# {'icon': 'https://tmssl.akamaized.net/images/berater_logo/small/831051_1606842298.png?lm=1606842298', 'full_name': 'T&C Sports Management', 'nationality': None, 'market_value': None}
# J. Timber
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Jorginho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/102017-1682590896.jpg?lm=1', 'full_name': 'Jorginho', 'nationality': 'Italy', 'market_value': '€35.00m'}
# Gonçalo Inácio
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/549006-1571744859.jpg?lm=1', 'full_name': 'Gonçalo Inácio', 'nationality': 'Portugal', 'market_value': '€30.00m'}
# Álvarez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/576024-1684920938.jpg?lm=1', 'full_name': 'Julián Álvarez', 'nationality': 'Argentina', 'market_value': '€50.00m'}
# Alex Sandro
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/79960-1661351746.jpg?lm=1', 'full_name': 'Alex Sandro', 'nationality': 'Brazil', 'market_value': '€3.00m'}
# Alonso
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/7476-1471439383.JPG?lm=1', 'full_name': 'Xabi Alonso', 'nationality': 'Spain', 'market_value': '-'}
# Everton
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/321239-1603795820.jpg?lm=1', 'full_name': 'Everton', 'nationality': 'Brazil', 'market_value': '€11.00m'}
# Džeko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/28396-1661268909.jpg?lm=1', 'full_name': 'Edin Dzeko', 'nationality': 'Bosnia-Herzegovina', 'market_value': '€4.00m'}
# Vanaken
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/137576-1616530175.jpg?lm=1', 'full_name': 'Hans Vanaken', 'nationality': 'Belgium', 'market_value': '€10.00m'}
# S. Thill
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Coates
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/102427-1666100911.jpg?lm=1', 'full_name': 'Sebastián Coates', 'nationality': 'Uruguay', 'market_value': '€5.00m'}
# Arnold
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/314353-1662621037.jpg?lm=1', 'full_name': 'Trent Alexander-Arnold', 'nationality': 'England', 'market_value': '€65.00m'}
# Cristiano
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/8198-1685035469.png?lm=1', 'full_name': 'Cristiano Ronaldo', 'nationality': 'Portugal', 'market_value': '€15.00m'}
# Zabarnyi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/659089-1665387692.png?lm=1', 'full_name': 'Ilya Zabarnyi', 'nationality': 'Ukraine', 'market_value': '€18.00m'}
# Fernando
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/7767-1683642827.jpg?lm=1', 'full_name': 'Fernando Torres', 'nationality': 'Spain', 'market_value': '-'}
# Fernando Costanza
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/524403-1658218291.png?lm=1', 'full_name': 'Fernando Costanza', 'nationality': 'Brazil', 'market_value': '€1.20m'}
# Dodô
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/401529-1663591985.jpg?lm=1', 'full_name': 'Dodô', 'nationality': 'Brazil', 'market_value': '€20.00m'}
# Barrios
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/58516-1407485900.jpg?lm=1', 'full_name': 'Lucas Barrios', 'nationality': 'Paraguay', 'market_value': '€100k'}
# Lacroix
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/434224-1657202248.jpg?lm=1', 'full_name': 'Maxence Lacroix', 'nationality': 'France', 'market_value': '€20.00m'}
# Hendry
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/363223-1672688260.jpg?lm=1', 'full_name': 'Jack Hendry', 'nationality': 'Scotland', 'market_value': '€3.00m'}
# Arboleda
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/385454-1678214888.jpg?lm=1', 'full_name': 'Cristian Dájome', 'nationality': 'Colombia', 'market_value': '€2.00m'}
# Dulanto
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/347382-1681761031.png?lm=1', 'full_name': 'Gustavo Dulanto', 'nationality': 'Peru', 'market_value': '€1.00m'}
# Bounou
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/207834-1668503728.jpg?lm=1', 'full_name': 'Bono', 'nationality': 'Morocco', 'market_value': '€12.00m'}
# Kobel
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/257814-1661412809.jpg?lm=1', 'full_name': 'Gregor Kobel', 'nationality': 'Switzerland', 'market_value': '€35.00m'}
# Mignolet
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/50219-1616529337.jpg?lm=1', 'full_name': 'Simon Mignolet', 'nationality': 'Belgium', 'market_value': '€3.20m'}
# Musso
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/242359-1663583047.jpg?lm=1', 'full_name': 'Juan Musso', 'nationality': 'Argentina', 'market_value': '€8.00m'}
# Pasveer
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/25520-1666951851.jpg?lm=1', 'full_name': 'Remko Pasveer', 'nationality': 'Netherlands', 'market_value': '€250k'}
# Grbić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/167342-1540456985.jpg?lm=1', 'full_name': 'Adrian Grbic', 'nationality': 'Austria', 'market_value': '€1.50m'}
# Diogo Costa
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/357153-1542105514.png?lm=1', 'full_name': 'Diogo Costa', 'nationality': 'Portugal', 'market_value': '€45.00m'}
# Ter Stegen
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/74857-1674465246.jpg?lm=1', 'full_name': 'Marc-André ter Stegen', 'nationality': 'Germany', 'market_value': '€35.00m'}
# Locatelli
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/265088-1630490000.jpg?lm=1', 'full_name': 'Manuel Locatelli', 'nationality': 'Italy', 'market_value': '€30.00m'}
# Diego Carlos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/329145-1568022060.jpg?lm=1', 'full_name': 'Diego Carlos', 'nationality': 'Brazil', 'market_value': '€30.00m'}
# Mount
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/346483-1683291495.jpg?lm=1', 'full_name': 'Mason Mount', 'nationality': 'England', 'market_value': '€65.00m'}
# Rabiot
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/182913-1681462009.jpg?lm=1', 'full_name': 'Adrien Rabiot', 'nationality': 'France', 'market_value': '€40.00m'}
# Sydorchuk
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/124182-1665388074.png?lm=1', 'full_name': 'Sergiy Sydorchuk', 'nationality': 'Ukraine', 'market_value': '€4.00m'}
# Maguire
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/177907-1663841733.jpg?lm=1', 'full_name': 'Harry Maguire', 'nationality': 'England', 'market_value': '€25.00m'}
# João Palhinha
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/257455-1684773447.jpg?lm=1', 'full_name': 'João Palhinha', 'nationality': 'Portugal', 'market_value': '€35.00m'}
# Tiago Djaló
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/420465-1666690517.jpg?lm=1', 'full_name': 'Tiago Djaló', 'nationality': 'Portugal', 'market_value': '€16.00m'}
# Moumi Ngamaleu
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/266768-1663086781.png?lm=1', 'full_name': 'Nicolas Moumi Ngamaleu', 'nationality': 'Cameroon', 'market_value': '€3.00m'}
# Perišić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/42460-1667991317.jpg?lm=1', 'full_name': 'Ivan Perisic', 'nationality': 'Croatia', 'market_value': '€10.00m'}
# Nkunku
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/344381-1663686834.jpg?lm=1', 'full_name': 'Christopher Nkunku', 'nationality': 'France', 'market_value': '€80.00m'}
# Traore
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/204103-1685622835.jpg?lm=1', 'full_name': 'Adama Traoré', 'nationality': 'Spain', 'market_value': '€12.00m'}
# Burak Yılmaz
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/34987-1622122750.jpg?lm=1', 'full_name': 'Burak Yilmaz', 'nationality': 'Turkey', 'market_value': '€1.00m'}
# Pedro Porro
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/553875-1602774481.jpg?lm=1', 'full_name': 'Pedro Porro', 'nationality': 'Spain', 'market_value': '€35.00m'}
# Lang
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/339332-1642424716.jpg?lm=1', 'full_name': 'Noa Lang', 'nationality': 'Netherlands', 'market_value': '€15.00m'}
# Clinton Mata
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/187718-1616529648.jpg?lm=1', 'full_name': 'Clinton Mata', 'nationality': 'Angola', 'market_value': '€4.50m'}
# Freuler
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/148252-1537772961.jpg?lm=1', 'full_name': 'Remo Freuler', 'nationality': 'Switzerland', 'market_value': '€10.00m'}
# Depay
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/167850-1668167349.jpg?lm=1', 'full_name': 'Memphis Depay', 'nationality': 'Netherlands', 'market_value': '€14.00m'}
# Gerard Moreno
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/177467-1601538911.jpg?lm=1', 'full_name': 'Gerard Moreno', 'nationality': 'Spain', 'market_value': '€20.00m'}
# Lo Celso
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/348795-1591195792.jpg?lm=1', 'full_name': 'Giovani Lo Celso', 'nationality': 'Argentina', 'market_value': '€14.00m'}
# F. de Jong
# {'icon': 'https://tmssl.akamaized.net/images/berater_logo/small/berater-default.png?lm=1520606995', 'full_name': 'Iconics Management', 'nationality': None, 'market_value': None}
# Morata
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/128223-1644496732.jpg?lm=1', 'full_name': 'Álvaro Morata', 'nationality': 'Spain', 'market_value': '€20.00m'}
# Bruno Fernandes
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/240306-1683882766.jpg?lm=1', 'full_name': 'Bruno Fernandes', 'nationality': 'Portugal', 'market_value': '€75.00m'}
# Griezmann
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/125781-1667568355.jpg?lm=1', 'full_name': 'Antoine Griezmann', 'nationality': 'France', 'market_value': '€25.00m'}
# Sučić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/502722-1661532237.png?lm=1', 'full_name': 'Luka Sucic', 'nationality': 'Croatia', 'market_value': '€18.00m'}
# Süle
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/166601-1661412949.jpg?lm=1', 'full_name': 'Niklas Süle', 'nationality': 'Germany', 'market_value': '€35.00m'}
# Yaremchuk
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/221958-1604923720.jpg?lm=1', 'full_name': 'Roman Yaremchuk', 'nationality': 'Ukraine', 'market_value': '€5.00m'}
# Sarabia
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/74230-1602692460.jpg?lm=1', 'full_name': 'Pablo Sarabia', 'nationality': 'Spain', 'market_value': '€16.00m'}
# Matheus Nunes
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/601883-1571746027.jpg?lm=1', 'full_name': 'Matheus Nunes', 'nationality': 'Portugal', 'market_value': '€45.00m'}
# James
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/88103-1540568385.jpg?lm=1', 'full_name': 'James Rodríguez', 'nationality': 'Colombia', 'market_value': '€6.00m'}
# Aebischer
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/237658-1669289063.jpg?lm=1', 'full_name': 'Michel Aebischer', 'nationality': 'Switzerland', 'market_value': '€4.00m'}
# Bellingham
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/581678-1661412719.jpg?lm=1', 'full_name': 'Jude Bellingham', 'nationality': 'England', 'market_value': '€120.00m'}
# Zinchenko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/203853-1662666167.jpg?lm=1', 'full_name': 'Oleksandr Zinchenko', 'nationality': 'Ukraine', 'market_value': '€40.00m'}
# De Ketelaere
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/435772-1659601388.jpg?lm=1', 'full_name': 'Charles De Ketelaere', 'nationality': 'Belgium', 'market_value': '€22.00m'}
# Čolak
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/77707-1663973566.png?lm=1', 'full_name': 'Emre Çolak', 'nationality': 'Turkey', 'market_value': '€100k'}
# Reus
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/7607-1476882942.jpg?lm=1', 'full_name': 'Xavi', 'nationality': 'Spain', 'market_value': '-'}
# Rakitskyy
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/89222-1665476487.jpg?lm=1', 'full_name': 'Yaroslav Rakitskyi', 'nationality': 'Ukraine', 'market_value': '€3.00m'}
# Barella
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/255942-1661353022.jpg?lm=1', 'full_name': 'Nicolò Barella', 'nationality': 'Italy', 'market_value': '€75.00m'}
# Innocent
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/66022-1572863420.jpg?lm=1', 'full_name': 'Innocent Emeghara', 'nationality': 'Switzerland', 'market_value': '-'}
# Taremi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/307058-1606396744.png?lm=1', 'full_name': 'Mehdi Taremi', 'nationality': 'Iran', 'market_value': '€18.00m'}
# João Mário
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/149729-1681390479.jpg?lm=1', 'full_name': 'João Mário', 'nationality': 'Portugal', 'market_value': '€14.00m'}
# Addo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/9790-1674688255.jpg?lm=1', 'full_name': 'Badr El Kaddouri', 'nationality': 'Morocco', 'market_value': '-'}
# Tsygankov
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/264372-1665388366.png?lm=1', 'full_name': 'Viktor Tsygankov', 'nationality': 'Ukraine', 'market_value': '€22.00m'}
# Elia
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/502670-1663578995.jpg?lm=1', 'full_name': 'Khvicha Kvaratskhelia', 'nationality': 'Georgia', 'market_value': '€85.00m'}
# De Vrij
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/111196-1663572651.jpg?lm=1', 'full_name': 'Stefan de Vrij', 'nationality': 'Netherlands', 'market_value': '€8.00m'}
# Sergio Busquets
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/65230-1668168379.jpg?lm=1', 'full_name': 'Sergio Busquets', 'nationality': 'Spain', 'market_value': '€5.00m'}
# Shaparenko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/368611-1665388008.png?lm=1', 'full_name': 'Mykola Shaparenko', 'nationality': 'Ukraine', 'market_value': '€9.00m'}
# Mukiele
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/348026-1672303364.jpg?lm=1', 'full_name': 'Nordi Mukiele', 'nationality': 'France', 'market_value': '€20.00m'}
# Wendel
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/228433-1669115150.png?lm=1', 'full_name': 'Wendell', 'nationality': 'Brazil', 'market_value': '€5.00m'}
# Meunier
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/100986-1662361426.jpg?lm=1', 'full_name': 'Thomas Meunier', 'nationality': 'Belgium', 'market_value': '€6.50m'}
# De Roon
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/133179-1663582942.jpg?lm=1', 'full_name': 'Marten de Roon', 'nationality': 'Netherlands', 'market_value': '€10.00m'}
# Nsoki
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/371141-1627313788.jpg?lm=1', 'full_name': 'Stanley Nsoki', 'nationality': 'France', 'market_value': '€8.50m'}
# Renan Lodi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/476352-1554733508.jpg?lm=1', 'full_name': 'Renan Lodi', 'nationality': 'Brazil', 'market_value': '€20.00m'}
# Davies
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/424204-1667830391.jpg?lm=1', 'full_name': 'Alphonso Davies', 'nationality': 'Canada', 'market_value': '€70.00m'}
# Maycon
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/421935-1641992736.png?lm=1', 'full_name': 'Maycon', 'nationality': 'Brazil', 'market_value': '€6.00m'}
# Carrasco
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/140776-1664969500.jpg?lm=1', 'full_name': 'Yannick Carrasco', 'nationality': 'Belgium', 'market_value': '€25.00m'}
# Cuadrado
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/91970-1663576912.jpg?lm=1', 'full_name': 'Juan Cuadrado', 'nationality': 'Colombia', 'market_value': '€4.00m'}
# Felipe
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/159372-1606396538.png?lm=1', 'full_name': 'Felipe Anderson', 'nationality': 'Brazil', 'market_value': '€15.00m'}
# Witsel
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/35047-1665067807.jpg?lm=1', 'full_name': 'Axel Witsel', 'nationality': 'Belgium', 'market_value': '€5.00m'}
# Neymar
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/68290-1669394812.jpg?lm=1', 'full_name': 'Neymar', 'nationality': 'Brazil', 'market_value': '€70.00m'}
# Bamba
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/292818-1599420401.jpg?lm=1', 'full_name': 'Jonathan Bamba', 'nationality': "Cote d'Ivoire", 'market_value': '€20.00m'}
# Dumfries
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/321528-1663572270.jpg?lm=1', 'full_name': 'Denzel Dumfries', 'nationality': 'Netherlands', 'market_value': '€28.00m'}
# Goretzka
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/153084-1667830008.jpg?lm=1', 'full_name': 'Leon Goretzka', 'nationality': 'Germany', 'market_value': '€65.00m'}
# Zapata
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/73794-1661508410.jpg?lm=1', 'full_name': 'Duván Zapata', 'nationality': 'Colombia', 'market_value': '€8.00m'}
# Coquelin
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/74869-1515684724.jpg?lm=1', 'full_name': 'Francis Coquelin', 'nationality': 'France', 'market_value': '€3.00m'}
# Ocampos
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/189441-1614951740.jpg?lm=1', 'full_name': 'Lucas Ocampos', 'nationality': 'Argentina', 'market_value': '€12.00m'}
# Lauper
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/254965-1533136141.jpg?lm=1', 'full_name': 'Sandro Lauper', 'nationality': 'Switzerland', 'market_value': '€1.70m'}
# Grealish
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/203460-1676499047.jpg?lm=1', 'full_name': 'Jack Grealish', 'nationality': 'England', 'market_value': '€70.00m'}
# Claudinho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/403315-1628946845.png?lm=1', 'full_name': 'Claudinho', 'nationality': 'Brazil', 'market_value': '€20.00m'}
# Otávio
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/231289-1668697777.jpg?lm=1', 'full_name': 'Otávio', 'nationality': 'Portugal', 'market_value': '€35.00m'}
# Feddal
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/129386-1602774425.jpg?lm=1', 'full_name': 'Zouhair Feddal', 'nationality': 'Morocco', 'market_value': '€1.30m'}
# Palomino
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/125020-1663582906.jpg?lm=1', 'full_name': 'José Luis Palomino', 'nationality': 'Argentina', 'market_value': '€2.50m'}
# T. Hernández
# {'icon': 'https://tmssl.akamaized.net/images/berater_logo/small/831051_1606842298.png?lm=1606842298', 'full_name': 'T&C Sports Management', 'nationality': None, 'market_value': None}
# Danilo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/145707-1663577215.jpg?lm=1', 'full_name': 'Danilo', 'nationality': 'Brazil', 'market_value': '€15.00m'}
# Mykolenko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/404842-1612462386.png?lm=1', 'full_name': 'Vitaliy Mykolenko', 'nationality': 'Ukraine', 'market_value': '€22.00m'}
# Syrota
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/505463-1665387772.png?lm=1', 'full_name': 'Oleksandr Syrota', 'nationality': 'Ukraine', 'market_value': '€3.00m'}
# Koundé
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/411975-1662585791.jpg?lm=1', 'full_name': 'Jules Koundé', 'nationality': 'France', 'market_value': '€60.00m'}
# Savić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/266302-1684856414.jpg?lm=1', 'full_name': 'Sergej Milinković-Savić', 'nationality': 'Serbia', 'market_value': '€50.00m'}
# Akanji
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/284730-1684165752.jpg?lm=1', 'full_name': 'Manuel Akanji', 'nationality': 'Switzerland', 'market_value': '€30.00m'}
# L. Nielsen
# {'icon': 'https://tmssl.akamaized.net/images/berater_logo/small/berater-default.png?lm=1520606995', 'full_name': 'Boutique Transfers and Management ApS', 'nationality': None, 'market_value': None}
# Marlon
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/273236-1627167047.png?lm=1', 'full_name': 'Marlon', 'nationality': 'Brazil', 'market_value': '€6.00m'}
# Mbemba
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/203348-1666814922.jpg?lm=1', 'full_name': 'Chancel Mbemba', 'nationality': 'DR Congo', 'market_value': '€20.00m'}
# Casteels
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/108880-1657202120.jpg?lm=1', 'full_name': 'Koen Casteels', 'nationality': 'Belgium', 'market_value': '€8.00m'}
# Ersin Destanoğlu
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/500091-1674487079.png?lm=1', 'full_name': 'Ersin Destanoglu', 'nationality': 'Turkey', 'market_value': '€5.00m'}
# Donnarumma
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/315858-1672304477.jpg?lm=1', 'full_name': 'Gianluigi Donnarumma', 'nationality': 'Italy', 'market_value': '€50.00m'}
# Gulácsi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/57071-1613997804.jpg?lm=1', 'full_name': 'Péter Gulácsi', 'nationality': 'Hungary', 'market_value': '€6.00m'}
# Bushchan
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/206888-1665387584.png?lm=1', 'full_name': 'Georgiy Bushchan', 'nationality': 'Ukraine', 'market_value': '€10.00m'}
# Athanasiadis
# ...
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/294746-1665388152.png?lm=1', 'full_name': 'Volodymyr Shepelev', 'nationality': 'Ukraine', 'market_value': '€2.50m'}
# Richards
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/32617-1409567817.jpg?lm=1', 'full_name': 'Micah Richards', 'nationality': 'England', 'market_value': '-'}
# Julien
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/196792-1662965628.jpg?lm=1', 'full_name': 'Julian Weigl', 'nationality': 'Germany', 'market_value': '€15.00m'}
# Oğuzhan Özyakup
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/77966-1635600902.jpeg?lm=1', 'full_name': 'Oguzhan Özyakup', 'nationality': 'Turkey', 'market_value': '€1.00m'}
# Daramy
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/574385-1624962062.jpg?lm=1', 'full_name': 'Mohamed Daramy', 'nationality': 'Denmark', 'market_value': '€6.00m'}
# Henrichs
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/202591-1663686588.jpg?lm=1', 'full_name': 'Benjamin Henrichs', 'nationality': 'Germany', 'market_value': '€15.00m'}
# Choupo-Moting
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/45660-1667830186.jpg?lm=1', 'full_name': 'Eric Maxim Choupo-Moting', 'nationality': 'Cameroon', 'market_value': '€6.00m'}
# Yusuf Yazıcı
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/386726-1645434932.png?lm=1', 'full_name': 'Yusuf Yazici', 'nationality': 'Turkey', 'market_value': '€9.00m'}
# Icardi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/68863-1671105169.png?lm=1', 'full_name': 'Mauro Icardi', 'nationality': 'Argentina', 'market_value': '€19.00m'}
# McAtee
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/583199-1633704255.jpg?lm=1', 'full_name': 'James McAtee', 'nationality': 'England', 'market_value': '€12.00m'}
# Lovato
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/459655-1608218015.jpg?lm=1', 'full_name': 'Matteo Lovato', 'nationality': 'Italy', 'market_value': '€6.00m'}
# Palmer
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/568177-1661441838.jpg?lm=1', 'full_name': 'Cole Palmer', 'nationality': 'England', 'market_value': '€15.00m'}
# Paulo Bernardo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/504090-1625667325.jpg?lm=1', 'full_name': 'Paulo Bernardo', 'nationality': 'Portugal', 'market_value': '€3.00m'}
# Kjærgaard
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Taylor
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/470394-1682332353.jpg?lm=1', 'full_name': 'Kenneth Taylor', 'nationality': 'Netherlands', 'market_value': '€14.00m'}
# Francisco Conceição
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/487474-1614847613.png?lm=1', 'full_name': 'Francisco Conceição', 'nationality': 'Portugal', 'market_value': '€8.00m'}
# F. Nmecha
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Pepê
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/343052-1539166309.jpg?lm=1', 'full_name': 'Nicolas Pépé', 'nationality': "Cote d'Ivoire", 'market_value': '€22.00m'}
# Al. Miranchuk
# {'icon': None, 'full_name': None, 'nationality': None, 'market_value': None}
# Edwards
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/314367-1653379978.jpg?lm=1', 'full_name': 'Marcus Edwards', 'nationality': 'England', 'market_value': '€30.00m'}
# Radonjić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/245078-1663596823.jpg?lm=1', 'full_name': 'Nemanja Radonjic', 'nationality': 'Serbia', 'market_value': '€4.00m'}
# Mengi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/548470-1681288000.jpg?lm=1', 'full_name': 'Teden Mengi', 'nationality': 'England', 'market_value': '€2.00m'}
# Wesley
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/475411-1683899212.jpg?lm=1', 'full_name': 'Wesley Fofana', 'nationality': 'France', 'market_value': '€65.00m'}
# Mandi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1', 'full_name': 'Luigi Allemandi', 'nationality': 'Italy', 'market_value': '-'}
# Kudus
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/543499-1668429218.jpg?lm=1', 'full_name': 'Mohammed Kudus', 'nationality': 'Ghana', 'market_value': '€30.00m'}
# Novoa
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/668276-1606146927.jpg?lm=1', 'full_name': 'Hugo Novoa', 'nationality': 'Spain', 'market_value': '€4.30m'}
# Lihadji
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/557610-1571645415.jpg?lm=1', 'full_name': 'Isaac Lihadji', 'nationality': 'France', 'market_value': '€1.20m'}
# Bernardo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/241641-1684311533.jpg?lm=1', 'full_name': 'Bernardo Silva', 'nationality': 'Portugal', 'market_value': '€80.00m'}
# Tijani
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/351792-1681599018.JPG?lm=1', 'full_name': 'David Tijanic', 'nationality': 'Slovenia', 'market_value': '€800k'}
# Ben Arfa
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/18900-1598304636.jpg?lm=1', 'full_name': 'Hatem Ben Arfa', 'nationality': 'France', 'market_value': '€500k'}
# Óscar Rodríguez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/284884-1448531300.jpg?lm=1', 'full_name': 'Óscar Rodríguez', 'nationality': 'Spain', 'market_value': '€8.00m'}
# Shoretire
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/640026-1612447506.jpg?lm=1', 'full_name': 'Shola Shoretire', 'nationality': 'England', 'market_value': '€4.00m'}
# Heaton
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/34130-1464863026.jpg?lm=1', 'full_name': 'Tom Heaton', 'nationality': 'England', 'market_value': '€600k'}
# Stanišić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/483046-1667830853.jpg?lm=1', 'full_name': 'Josip Stanisic', 'nationality': 'Croatia', 'market_value': '€12.00m'}
# Knauff
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/429874-1663065826.jpg?lm=1', 'full_name': 'Ansgar Knauff', 'nationality': 'Germany', 'market_value': '€10.00m'}
# Maldini
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/5803-1570438594.jpg?lm=1', 'full_name': 'Paolo Maldini', 'nationality': 'Italy', 'market_value': '-'}
# Moukoko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/467720-1661413121.jpg?lm=1', 'full_name': 'Youssoufa Moukoko', 'nationality': 'Germany', 'market_value': '€30.00m'}
# Iván Romero
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1', 'full_name': 'Iván Romero', 'nationality': 'Spain', 'market_value': '-'}
# Flávio Nazinho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/668587-1571749462.jpg?lm=1', 'full_name': 'Nazinho', 'nationality': 'Portugal', 'market_value': '€1.00m'}
# Balde
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/238752-1674624241.png?lm=1', 'full_name': 'Keita Baldé', 'nationality': 'Senegal', 'market_value': '€2.50m'}
# Tillman
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/467437-1632918655.png?lm=1', 'full_name': 'Malik Tillman', 'nationality': 'United States', 'market_value': '€4.50m'}
# Peña
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/350219-1672303440.jpg?lm=1', 'full_name': 'Fabián Ruiz', 'nationality': 'Spain', 'market_value': '€38.00m'}
# Ricard Puig
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/331511-1678024462.jpg?lm=1', 'full_name': 'Riqui Puig', 'nationality': 'Spain', 'market_value': '€8.00m'}
# Berkay Vardar
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/724350-1667044972.png?lm=1', 'full_name': 'Berkay Vardar', 'nationality': 'Turkey', 'market_value': '€550k'}
# Carson
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/14555-1666733622.jpg?lm=1', 'full_name': 'Scott Carson', 'nationality': 'England', 'market_value': '€250k'}
# Eric Ramirez
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/428746-1685896298.png?lm=1', 'full_name': 'Eric Ramírez', 'nationality': 'Venezuela', 'market_value': '€900k'}
# Cojocaru
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/200616-1641378536.png?lm=1', 'full_name': 'Valentin Cojocaru', 'nationality': 'Romania', 'market_value': '€900k'}
# Javi Serrano
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/668177-1646643743.jpg?lm=1', 'full_name': 'Javi Serrano', 'nationality': 'Spain', 'market_value': '€700k'}
# Agüero
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/26399-1580460866.jpg?lm=1', 'full_name': 'Sergio Agüero', 'nationality': 'Argentina', 'market_value': '-'}
# Ramsey
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/50057-1518795716.jpg?lm=1', 'full_name': 'Aaron Ramsey', 'nationality': 'Wales', 'market_value': '€3.00m'}
# Kravtsov
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/607814-1602312817.png?lm=1', 'full_name': 'Kirill Kravtsov', 'nationality': 'Russia', 'market_value': '€1.00m'}
# Bradarić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/357796-1663668545.jpg?lm=1', 'full_name': 'Domagoj Bradaric', 'nationality': 'Croatia', 'market_value': '€7.00m'}
# Ozdoev
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/137206-1666267770.png?lm=1', 'full_name': 'Magomed Ozdoev', 'nationality': 'Russia', 'market_value': '€2.20m'}
# Bruno Costa
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/344519-1542106011.png?lm=1', 'full_name': 'Bruno Costa', 'nationality': 'Portugal', 'market_value': '€1.50m'}
# Raba
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/287579-1663591493.jpg?lm=1', 'full_name': 'Sofyan Amrabat', 'nationality': 'Morocco', 'market_value': '€30.00m'}
# Iborra
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/65467-1447240009.jpg?lm=1', 'full_name': 'Vicente Iborra', 'nationality': 'Spain', 'market_value': '€1.20m'}
# Bonnah
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/508637-1594305922.jpg?lm=1', 'full_name': 'Solomon Bonnah', 'nationality': 'Netherlands', 'market_value': '€500k'}
# Sensi
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/296622-1664970818.jpg?lm=1', 'full_name': 'Marco Asensio', 'nationality': 'Spain', 'market_value': '€25.00m'}
# Lednev
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/423606-1612460939.png?lm=1', 'full_name': 'Bogdan Lednev', 'nationality': 'Ukraine', 'market_value': '€800k'}
# Zhegrova
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/496857-1642174107.jpg?lm=1', 'full_name': 'Edon Zhegrova', 'nationality': 'Kosovo', 'market_value': '€7.00m'}
# Seferović
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/109256-1671105391.png?lm=1', 'full_name': 'Haris Seferovic', 'nationality': 'Switzerland', 'market_value': '€4.00m'}
# Zakaria
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/334526-1667990520.jpg?lm=1', 'full_name': 'Denis Zakaria', 'nationality': 'Switzerland', 'market_value': '€20.00m'}
# Dário Essugo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/670717-1616406134.jpg?lm=1', 'full_name': 'Dário Essugo', 'nationality': 'Portugal', 'market_value': '€2.00m'}
# Spielmann
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/192653-1651736433.png?lm=1', 'full_name': 'Marvin Spielmann', 'nationality': 'Switzerland', 'market_value': '€250k'}
# Izquierdo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/147094-1486755753.jpg?lm=1', 'full_name': 'José Izquierdo', 'nationality': 'Colombia', 'market_value': '€800k'}
# Chiellini
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/29260-1678025858.jpg?lm=1', 'full_name': 'Giorgio Chiellini', 'nationality': 'Italy', 'market_value': '€1.00m'}
# Dina Ebimbe
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/536482-1663065378.jpg?lm=1', 'full_name': 'Junior Dina Ebimbe', 'nationality': 'France', 'market_value': '€7.50m'}
# Sulejmani
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/36080-1533136216.jpg?lm=1', 'full_name': 'Miralem Sulejmani', 'nationality': 'Serbia', 'market_value': '€200k'}
# Delap
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/610849-1601282009.jpg?lm=1', 'full_name': 'Liam Delap', 'nationality': 'England', 'market_value': '€5.00m'}
# Mbete
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/609883-1650877535.jpg?lm=1', 'full_name': 'Luke Mbete', 'nationality': 'England', 'market_value': '€2.00m'}
# Kolarov
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/46156-1488890886.jpg?lm=1', 'full_name': 'Aleksandar Kolarov', 'nationality': 'Serbia', 'market_value': '-'}
# Šimić
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/s_2540_123_2012_11_22_1.jpg?lm=1', 'full_name': 'Dario Simic', 'nationality': 'Croatia', 'market_value': '-'}
# Guindo
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/34706-1446654769.jpg?lm=1', 'full_name': 'Dani', 'nationality': 'Portugal', 'market_value': '-'}
# Dentinho
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/52787-1569591301.png?lm=1', 'full_name': 'Dentinho', 'nationality': 'Brazil', 'market_value': '€250k'}
# Shevchenko
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/3522-1570438190.jpg?lm=1', 'full_name': 'Andriy Shevchenko', 'nationality': 'Ukraine', 'market_value': '-'}
# Maier
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/89550-1434713976.jpg?lm=1', 'full_name': 'Sepp Maier', 'nationality': 'Germany', 'market_value': '-'}
# Luca Pellegrini
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/346567-1663065246.jpg?lm=1', 'full_name': 'Luca Pellegrini', 'nationality': 'Italy', 'market_value': '€7.00m'}
# Kuznetsov
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/101021-1581444119.jpg?lm=1', 'full_name': 'Oleg Kuznetsov', 'nationality': 'Ukraine', 'market_value': '-'}
# Eile
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1', 'full_name': 'Walter Weiler', 'nationality': 'Switzerland', 'market_value': '-'}
# Ginczek
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/79501-1657114252.jpg?lm=1', 'full_name': 'Daniel Ginczek', 'nationality': 'Germany', 'market_value': '€600k'}
# Savage
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/3797-1416989780.jpg?lm=1', 'full_name': 'Robbie Savage', 'nationality': 'Wales', 'market_value': '-'}
# Iqbal
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/default.jpg?lm=1', 'full_name': 'Kamran Ali Iqbal', 'nationality': 'Pakistan', 'market_value': '-'}
# Da Graca
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/111627-1411386200.JPG?lm=1', 'full_name': 'Ryan Mendes', 'nationality': 'Cape Verde', 'market_value': '€1.00m'}
# Miretti
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/571607-1652773586.jpg?lm=1', 'full_name': 'Fabio Miretti', 'nationality': 'Italy', 'market_value': '€15.00m'}
# Gil Dias
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/329723-1643888945.jpg?lm=1', 'full_name': 'Gil Dias', 'nationality': 'Portugal', 'market_value': '€2.00m'}
# Rodrigo Ribeiro
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/s_52941_4064_2012_1.jpg?lm=1', 'full_name': 'Rodrigo Souto', 'nationality': 'Brazil', 'market_value': '-'}
# Cojocari
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/49108-1629449049.png?lm=1', 'full_name': 'Andrei Cojocari', 'nationality': 'Moldova', 'market_value': '€150k'}
# Maouassa
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/357072-1630503943.jpg?lm=1', 'full_name': 'Faitout Maouassa', 'nationality': 'France', 'market_value': '€5.00m'}
# Zesiger
# {'icon': 'https://img.a.transfermarkt.technology/portrait/small/382478-1683103422.jpg?lm=1', 'full_name': 'Cédric Zesiger', 'nationality': 'Switzerland', 'market_value': '€5.50m'}

# %% [markdown]
# #### Fetch crime stats from Wikipedia:
# Download crime stats (intentional homicides) for all countries in the world (0.0-10.0)

# %%
import parsel


def crime_from_wiki():
    """scrape from wikipedia and yield results"""
    url = "https://en.wikipedia.org/wiki/List_of_countries_by_intentional_homicide_rate"
    with requests.Session() as session:
        req = session.get(url)
        response = parsel.Selector(req.text)
        table = response.xpath("//table[contains(@class,'static-row-numbers')]")
        body = table.xpath("./tbody//tr")
        for row in body:
            country = row.xpath("./td[1]//a/text()").get()
            if country:
                country = country.strip("*")
                country = country.strip()
                count_p_100k = float(row.xpath("./td[4]/text()").get())
                yield {"country":country, "count_p_100k":count_p_100k}

# Collect from Wikipedia
with MongoContext() as client:
    db= client[mongoDB]
    collection = db["countries"]
    collection.drop()
    for country in crime_from_wiki():
        collection.insert_one(country)

    for x in collection.find():
        print(x)
# Out:
# {'_id': ObjectId('648f35f6cedd83ded33bc567'), 'country': 'Afghanistan', 'count_p_100k': 6.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc568'), 'country': 'Albania', 'count_p_100k': 2.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc569'), 'country': 'Algeria', 'count_p_100k': 1.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc56a'), 'country': 'Andorra', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc56b'), 'country': 'Angola', 'count_p_100k': 4.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc56c'), 'country': 'Anguilla', 'count_p_100k': 28.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc56d'), 'country': 'Antigua and Barbuda', 'count_p_100k': 9.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc56e'), 'country': 'Argentina', 'count_p_100k': 5.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc56f'), 'country': 'Armenia', 'count_p_100k': 1.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc570'), 'country': 'Aruba', 'count_p_100k': 1.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc571'), 'country': 'Australia', 'count_p_100k': 0.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc572'), 'country': 'Austria', 'count_p_100k': 0.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc573'), 'country': 'Azerbaijan', 'count_p_100k': 2.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc574'), 'country': 'Bahamas', 'count_p_100k': 18.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc575'), 'country': 'Bahrain', 'count_p_100k': 0.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc576'), 'country': 'Bangladesh', 'count_p_100k': 2.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc577'), 'country': 'Barbados', 'count_p_100k': 14.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc578'), 'country': 'Belarus', 'count_p_100k': 2.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc579'), 'country': 'Belgium', 'count_p_100k': 1.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc57a'), 'country': 'Belize', 'count_p_100k': 25.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc57b'), 'country': 'Benin', 'count_p_100k': 1.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc57c'), 'country': 'Bermuda', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc57d'), 'country': 'Bhutan', 'count_p_100k': 2.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc57e'), 'country': 'Bolivia', 'count_p_100k': 7.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc57f'), 'country': 'Bosnia and Herzegovina', 'count_p_100k': 1.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc580'), 'country': 'Botswana', 'count_p_100k': 15.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc581'), 'country': 'Brazil', 'count_p_100k': 22.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc582'), 'country': 'British Virgin Islands', 'count_p_100k': 8.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc583'), 'country': 'Brunei', 'count_p_100k': 0.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc584'), 'country': 'Bulgaria', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc585'), 'country': 'Burkina Faso', 'count_p_100k': 1.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc586'), 'country': 'Burundi', 'count_p_100k': 6.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc587'), 'country': 'Cape Verde', 'count_p_100k': 6.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc588'), 'country': 'Cambodia', 'count_p_100k': 1.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc589'), 'country': 'Cameroon', 'count_p_100k': 1.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc58a'), 'country': 'Canada', 'count_p_100k': 2.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc58b'), 'country': 'Cayman Islands', 'count_p_100k': 8.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc58c'), 'country': 'Central African Republic', 'count_p_100k': 20.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc58d'), 'country': 'Channel Islands', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc58e'), 'country': 'Chile', 'count_p_100k': 4.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc58f'), 'country': 'China', 'count_p_100k': 0.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc590'), 'country': 'Colombia', 'count_p_100k': 22.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc591'), 'country': 'Costa Rica', 'count_p_100k': 11.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc592'), 'country': 'Croatia', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc593'), 'country': 'Cuba', 'count_p_100k': 5.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc594'), 'country': 'Curaçao', 'count_p_100k': 19.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc595'), 'country': 'Cyprus', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc596'), 'country': 'Czech Republic', 'count_p_100k': 0.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc597'), 'country': 'Denmark', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc598'), 'country': 'Dominica', 'count_p_100k': 20.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc599'), 'country': 'Dominican Republic', 'count_p_100k': 8.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc59a'), 'country': 'Ecuador', 'count_p_100k': 7.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc59b'), 'country': 'Egypt', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc59c'), 'country': 'El Salvador', 'count_p_100k': 37.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc59d'), 'country': 'England and Wales', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc59e'), 'country': 'Estonia', 'count_p_100k': 3.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc59f'), 'country': 'Eswatini', 'count_p_100k': 11.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a0'), 'country': 'Ethiopia', 'count_p_100k': 8.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a1'), 'country': 'Finland', 'count_p_100k': 1.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a2'), 'country': 'France', 'count_p_100k': 1.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a3'), 'country': 'French Guiana', 'count_p_100k': 13.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a4'), 'country': 'Georgia', 'count_p_100k': 1.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a5'), 'country': 'Germany', 'count_p_100k': 0.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a6'), 'country': 'Ghana', 'count_p_100k': 2.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a7'), 'country': 'Gibraltar', 'count_p_100k': 3.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a8'), 'country': 'Greece', 'count_p_100k': 0.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5a9'), 'country': 'Greenland', 'count_p_100k': 5.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5aa'), 'country': 'Grenada', 'count_p_100k': 12.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ab'), 'country': 'Guadeloupe', 'count_p_100k': 5.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ac'), 'country': 'Guatemala', 'count_p_100k': 17.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ad'), 'country': 'Guinea-Bissau', 'count_p_100k': 1.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ae'), 'country': 'Guyana', 'count_p_100k': 20.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5af'), 'country': 'Haiti', 'count_p_100k': 6.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b0'), 'country': 'Holy See', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b1'), 'country': 'Honduras', 'count_p_100k': 36.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b2'), 'country': 'Hong Kong', 'count_p_100k': 0.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b3'), 'country': 'Hungary', 'count_p_100k': 0.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b4'), 'country': 'Iceland', 'count_p_100k': 1.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b5'), 'country': 'India', 'count_p_100k': 3.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b6'), 'country': 'Indonesia', 'count_p_100k': 0.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b7'), 'country': 'Iran', 'count_p_100k': 2.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b8'), 'country': 'Iraq', 'count_p_100k': 10.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5b9'), 'country': 'Iraq (excluding Kurdistan)', 'count_p_100k': 10.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ba'), 'country': 'Ireland', 'count_p_100k': 0.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5bb'), 'country': 'Isle of Man', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5bc'), 'country': 'Israel', 'count_p_100k': 1.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5bd'), 'country': 'Italy', 'count_p_100k': 0.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5be'), 'country': 'Jamaica', 'count_p_100k': 44.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5bf'), 'country': 'Japan', 'count_p_100k': 0.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c0'), 'country': 'Jordan', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c1'), 'country': 'Kazakhstan', 'count_p_100k': 3.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c2'), 'country': 'Kenya', 'count_p_100k': 4.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c3'), 'country': 'Kosovo', 'count_p_100k': 2.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c4'), 'country': 'Kurdistan Region (Iraq)', 'count_p_100k': 2.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c5'), 'country': 'Kuwait', 'count_p_100k': 1.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c6'), 'country': 'Kyrgyzstan', 'count_p_100k': 1.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c7'), 'country': 'Latvia', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c8'), 'country': 'Lebanon', 'count_p_100k': 1.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5c9'), 'country': 'Lesotho', 'count_p_100k': 43.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ca'), 'country': 'Liberia', 'count_p_100k': 3.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5cb'), 'country': 'Liechtenstein', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5cc'), 'country': 'Lithuania', 'count_p_100k': 3.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5cd'), 'country': 'Luxembourg', 'count_p_100k': 0.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ce'), 'country': 'Macau', 'count_p_100k': 0.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5cf'), 'country': 'Malawi', 'count_p_100k': 1.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d0'), 'country': 'Malaysia', 'count_p_100k': 2.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d1'), 'country': 'Maldives', 'count_p_100k': 0.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d2'), 'country': 'Malta', 'count_p_100k': 1.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d3'), 'country': 'Martinique', 'count_p_100k': 2.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d4'), 'country': 'Mauritius', 'count_p_100k': 2.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d5'), 'country': 'Mayotte', 'count_p_100k': 5.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d6'), 'country': 'Mexico', 'count_p_100k': 28.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d7'), 'country': 'Monaco', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d8'), 'country': 'Mongolia', 'count_p_100k': 6.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5d9'), 'country': 'Montenegro', 'count_p_100k': 2.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5da'), 'country': 'Montserrat', 'count_p_100k': 20.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5db'), 'country': 'Morocco', 'count_p_100k': 1.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5dc'), 'country': 'Mozambique', 'count_p_100k': 3.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5dd'), 'country': 'Myanmar', 'count_p_100k': 28.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5de'), 'country': 'Namibia', 'count_p_100k': 11.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5df'), 'country': 'Nepal', 'count_p_100k': 2.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e0'), 'country': 'Netherlands', 'count_p_100k': 0.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e1'), 'country': 'New Zealand', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e2'), 'country': 'Nicaragua', 'count_p_100k': 7.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e3'), 'country': 'Niger', 'count_p_100k': 4.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e4'), 'country': 'Nigeria', 'count_p_100k': 22.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e5'), 'country': 'Northern Ireland', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e6'), 'country': 'Norway', 'count_p_100k': 0.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e7'), 'country': 'Oman', 'count_p_100k': 0.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e8'), 'country': 'Pakistan', 'count_p_100k': 3.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5e9'), 'country': 'Panama', 'count_p_100k': 11.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ea'), 'country': 'Paraguay', 'count_p_100k': 6.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5eb'), 'country': 'Peru', 'count_p_100k': 7.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ec'), 'country': 'Philippines', 'count_p_100k': 4.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ed'), 'country': 'Poland', 'count_p_100k': 0.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ee'), 'country': 'Portugal', 'count_p_100k': 0.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ef'), 'country': 'Puerto Rico', 'count_p_100k': 18.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f0'), 'country': 'Qatar', 'count_p_100k': 0.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f1'), 'country': 'South Korea', 'count_p_100k': 0.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f2'), 'country': 'Moldova', 'count_p_100k': 2.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f3'), 'country': 'North Macedonia', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f4'), 'country': 'Réunion', 'count_p_100k': 1.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f5'), 'country': 'Romania', 'count_p_100k': 1.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f6'), 'country': 'Russia', 'count_p_100k': 6.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f7'), 'country': 'Rwanda', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f8'), 'country': 'Saint Helena', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5f9'), 'country': 'Saint Kitts and Nevis', 'count_p_100k': 18.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5fa'), 'country': 'Saint Lucia', 'count_p_100k': 28.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc5fb'), 'country': 'Saint Martin', 'count_p_100k': 27.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc5fc'), 'country': 'Saint Pierre and Miquelon', 'count_p_100k': 15.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc5fd'), 'country': 'Saint Vincent and the Grenadines', 'count_p_100k': 17.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc5fe'), 'country': 'San Marino', 'count_p_100k': 0.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc5ff'), 'country': 'São Tomé and Príncipe', 'count_p_100k': 3.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc600'), 'country': 'Saudi Arabia', 'count_p_100k': 0.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc601'), 'country': 'Scotland', 'count_p_100k': 1.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc602'), 'country': 'Senegal', 'count_p_100k': 0.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc603'), 'country': 'Serbia', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc604'), 'country': 'Seychelles', 'count_p_100k': 10.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc605'), 'country': 'Sierra Leone', 'count_p_100k': 1.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc606'), 'country': 'Singapore', 'count_p_100k': 0.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc607'), 'country': 'Slovakia', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc608'), 'country': 'Slovenia', 'count_p_100k': 0.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc609'), 'country': 'South Africa', 'count_p_100k': 33.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc60a'), 'country': 'South Sudan', 'count_p_100k': 14.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc60b'), 'country': 'Spain', 'count_p_100k': 0.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc60c'), 'country': 'Sri Lanka', 'count_p_100k': 3.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc60d'), 'country': 'Palestine', 'count_p_100k': 1.0}
# {'_id': ObjectId('648f35f6cedd83ded33bc60e'), 'country': 'Sudan', 'count_p_100k': 5.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc60f'), 'country': 'Suriname', 'count_p_100k': 9.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc610'), 'country': 'Sweden', 'count_p_100k': 1.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc611'), 'country': 'Switzerland', 'count_p_100k': 0.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc612'), 'country': 'Syria', 'count_p_100k': 0.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc613'), 'country': 'Taiwan', 'count_p_100k': 0.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc614'), 'country': 'Tajikistan', 'count_p_100k': 0.9}
# {'_id': ObjectId('648f35f6cedd83ded33bc615'), 'country': 'Thailand', 'count_p_100k': 2.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc616'), 'country': 'East Timor', 'count_p_100k': 4.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc617'), 'country': 'Trinidad and Tobago', 'count_p_100k': 38.6}
# {'_id': ObjectId('648f35f6cedd83ded33bc618'), 'country': 'Tunisia', 'count_p_100k': 4.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc619'), 'country': 'Turkey', 'count_p_100k': 2.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc61a'), 'country': 'Turkmenistan', 'count_p_100k': 4.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc61b'), 'country': 'Turks and Caicos Islands', 'count_p_100k': 5.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc61c'), 'country': 'Uganda', 'count_p_100k': 9.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc61d'), 'country': 'Ukraine', 'count_p_100k': 6.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc61e'), 'country': 'United Arab Emirates', 'count_p_100k': 0.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc61f'), 'country': 'United Kingdom', 'count_p_100k': 1.1}
# {'_id': ObjectId('648f35f6cedd83ded33bc620'), 'country': 'Tanzania', 'count_p_100k': 6.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc621'), 'country': 'United States', 'count_p_100k': 6.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc622'), 'country': 'U.S. Virgin Islands', 'count_p_100k': 49.3}
# {'_id': ObjectId('648f35f6cedd83ded33bc623'), 'country': 'Uruguay', 'count_p_100k': 9.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc624'), 'country': 'Uzbekistan', 'count_p_100k': 1.2}
# {'_id': ObjectId('648f35f6cedd83ded33bc625'), 'country': 'Venezuela', 'count_p_100k': 36.7}
# {'_id': ObjectId('648f35f6cedd83ded33bc626'), 'country': 'Vietnam', 'count_p_100k': 1.5}
# {'_id': ObjectId('648f35f6cedd83ded33bc627'), 'country': 'Yemen', 'count_p_100k': 6.8}
# {'_id': ObjectId('648f35f6cedd83ded33bc628'), 'country': 'Zambia', 'count_p_100k': 5.4}
# {'_id': ObjectId('648f35f6cedd83ded33bc629'), 'country': 'Zimbabwe', 'count_p_100k': 7.5}

# %% [markdown]
# ## Transform Data
# In order to analyze the data we apply type conversions on selected attributes

# %%
TYPE_CONVERSIONS = {"minutes_played": "int",
                    'match_played': "int", 'goals': "int", 'assists': "int", 'distance_covered': 'float',
                    'fouls_committed': "int", 'fouls_suffered': "int", 'red': "int", 'yellow': "int",
                    'cross_accuracy': "int", 'cross_attempted': "int", 'cross_complted': "int",
                    'freekicks_taken': "int", 'pass_accuracy': "float", 'pass_attempted': "int",
                    'pass_completed': "int",
                    'balls_recoverd': "int",
                    'clearance_attempted': "int",
                    't_lost': "int",
                    't_won': "int",
                    'tackles': "int"
                    }

def type_converter(item: dict, definitions) -> dict:
    """converts all values that are in a given type key"""
    new_item = dict()
    for k, v in item.items():
        if k in definitions:
            if definitions[k] == "int":
                try:
                    float(v)
                    v = int(v)
                except:
                    v = None
            elif definitions[k] == "float":
                try:
                    v = float(v)
                except:
                    v = None

        new_item[k] = v
    return new_item

def transform_raw_data():
    with MongoContext() as client:
        db = client[mongoDB]
        raw = db[UEFA_RAW_DATA]
        collection = db["players"]
        collection.drop()
        for doc in raw.find():
            cleaned_item = type_converter(doc, TYPE_CONVERSIONS)
            collection.insert_one(cleaned_item)

transform_raw_data()

# %% [markdown]
# ### Metadata in MongoDB
# #### Collections
# ##### Players:
# Example data entry from a soccer player:
#
# ```{'_id': ObjectId('643c1b35afd7d39c21e6dbf8'),'player_name': 'Courtois', 'club': 'Real Madrid', 'position': 'Goalkeeper', 'minutes_played': 1230, 'match_played': 13, 'goals': 0, 'assists': 0, 'distance_covered': 64.2, 'cross_accuracy': 0, 'cross_attempted': 0, 'cross_complted': 0, 'freekicks_taken': 27, 'pass_accuracy': 76.7, 'pass_attempted': 483, 'pass_completed': 365, 'serial': 447, 'full_name': 'Thibaut Courtois', 'icon': 'https://img.a.transfermarkt.technology/portrait/small/108390-1665067957.jpg?lm=1', 'market_value': '€60.00m', 'nationality': 'Belgium'}```
#
# ##### Countries:
# Example data entry for the crime stats:
#
# `{'_id': ObjectId('643c37c7afd7d39c21e6dfc0'), 'country': 'Afghanistan', 'count_p_100k': 6.7}`
#
# ##### World Bank GDP
# Example data entry of the World Bank Data:
# `{
#   'indicator': {
#     'id': 'NY.GDP.MKTP.CD',
#     'value': 'GDP (current US$)'
#   },
#   'country': {
#     'id': 'ZH',
#     'value': 'Africa Eastern and Southern'
#   },
#   'countryiso3code': 'AFE',
#   'date': '2021',
#   'value': 1089454323810.36,
#   'obs_status': '',
#   'decimal': 0,
#   'gdp_eur': 1000772741852.1967
# }`

# %% [markdown]
# ## Data Cleaning
# Data Cleaning of `world_bank_gdp` Mongo-Collection is not necessary due to the API arguments which already make sure non-empty values are filtered.
# <>

# %% [markdown]
# ## Data Analysis
# <>

# %% [markdown]
# ## Data Output
# <>
