# %% [markdown]
# # Data Analysis with Spark Sql
# this notebook aims to provide a deeper understanding of the processed data, to give context to the upcomming visualizations

# %% [markdown]
# ### Spark Session
# establish a connector between MongoDB and Spark to create Spark Tables

# %%
# imports
from config import MONGO_HOST_REMOTE, MONGO_DB_REMOTE
import pandas as pd
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession, SQLContext
print(f"pyspark version: {pyspark.__version__}")
# Out:
# pyspark version: 3.3.2

# %%
# set configuration to install java packages of mongo-spark connector
spark_conf = pyspark.SparkConf().set("spark.jars.packages",
                              "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1")\
                            .setAppName("My App")

# %%
# start spark session
spark = SparkSession.builder \
    .config(conf=spark_conf) \
    .getOrCreate()

# %%
# Create uri for host and db to access mongo
uri =  f"{MONGO_HOST_REMOTE}/{MONGO_DB_REMOTE}"


collections = {
    "players": "raw_players",
    "gdp": "world_bank_gdp",
    "countries": "countries"
}
# turn every collection into a spark table
for table, collection in collections.items():
    df = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("uri", uri + "." + collection).load()
    df.createOrReplaceTempView(table)

# %% [markdown]
# # Analysis
# all collections have been turned into spark tables. Now we can start analysing

# %% [markdown]
# ### Analyze players data

# %%
def show_headers(data: list):
    return pd.DataFrame(columns=["Attributes"], data=data)

# %%
query = """SELECT * FROM players LIMIT 0"""
df = spark.sql(query)
pd_df = show_headers(df.columns)
pd_df
# Out:
#              Attributes
# 0                   _id
# 1               assists
# 2        balls_recoverd
# 3   clearance_attempted
# 4                  club
# 5        cross_accuracy
# 6       cross_attempted
# 7        cross_complted
# 8      distance_covered
# 9       fouls_committed
# 10       fouls_suffered
# 11      freekicks_taken
# 12            full_name
# 13                goals
# 14                 icon
# 15         market_value
# 16         match_played
# 17       minutes_played
# 18          nationality
# 19        pass_accuracy
# 20       pass_attempted
# 21       pass_completed
# 22          player_name
# 23             position
# 24                  red
# 25               serial
# 26               t_lost
# 27                t_won
# 28              tackles
# 29               yellow

# %% [markdown]
# ### Top 10 Rows from Table "players"

# %%
# let the analysis begin
query = """SELECT * FROM players LIMIT 10"""
df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df
# Out:
#                            _id  assists  balls_recoverd  clearance_attempted  \
# 0  (648eddf3583fa9e84fb89e73,)        0             NaN                  NaN
# 1  (648eddf3583fa9e84fb89e74,)        6            29.0                  0.0
# 2  (648eddf3583fa9e84fb89e75,)        1             6.0                 10.0
# 3  (648eddf3583fa9e84fb89e76,)        4            39.0                  4.0
# 4  (648eddf3583fa9e84fb89e77,)        0            76.0                 32.0
# 5  (648eddf3583fa9e84fb89e78,)        0            49.0                 28.0
# 6  (648eddf3583fa9e84fb89e79,)        1            50.0                 30.0
# 7  (648eddf3583fa9e84fb89e7a,)        0            76.0                 19.0
# 8  (648eddf3583fa9e84fb89e7b,)        0            37.0                  4.0
# 9  (648eddf3583fa9e84fb89e7c,)        2            36.0                 15.0
#
#           club  cross_accuracy  cross_attempted  cross_complted  \
# 0  Real Madrid               0                0               0
# 1  Real Madrid              31               19               6
# 2  Real Madrid              20               10               2
# 3  Real Madrid              25               12               3
# 4  Real Madrid               0                2               0
# 5  Real Madrid              11               17               2
# 6  Real Madrid              34               23               8
# 7  Real Madrid              25                4               1
# 8  Real Madrid              20               34               7
# 9  Real Madrid               0                0               0
#
#   distance_covered  fouls_committed  ...  pass_attempted  pass_completed  \
# 0             64.2              NaN  ...             483             365
# 1            133.0             13.0  ...             451             377
# 2            121.5              2.0  ...             523             433
# 3            124.5              3.0  ...             799             723
# 4            110.4             17.0  ...             643             563
# 5            112.3              9.0  ...             657             606
# 6            112.8             15.0  ...             576             503
# 7            107.6             17.0  ...             538             482
# 8            116.5              7.0  ...             814             752
# 9             96.3              7.0  ...             208             173
#
#        player_name    position  red serial  t_lost  t_won tackles  yellow
# 0         Courtois  Goalkeeper  NaN    447     NaN    NaN     NaN     NaN
# 1  Vinícius Júnior     Forward  1.0    121     8.0    3.0    11.0     0.0
# 2          Benzema     Forward  1.0    428     0.0    1.0     1.0     0.0
# 3           Modrić  Midfielder  1.0     54     6.0    3.0     9.0     0.0
# 4     Éder Militão    Defender  4.0      1    13.0    6.0    19.0     0.0
# 5            Alaba    Defender  1.0     22     6.0   12.0    18.0     0.0
# 6         Carvajal    Defender  3.0     21     6.0    6.0    12.0     0.0
# 7         Casemiro  Midfielder  3.0      1    18.0   13.0    31.0     0.0
# 8            Kroos  Midfielder  0.0     64     6.0    5.0    11.0     0.0
# 9            Mendy    Defender  3.0     70     1.0    5.0     6.0     0.0
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Average fouls per position

# %%
query = """SELECT position, AVG(fouls_committed) as average_fouls_committed FROM players GROUP BY position ORDER BY average_fouls_committed DESC;"""
df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df
# Out:
#      position  average_fouls_committed
# 0  Midfielder                 5.521739
# 1    Defender                 4.617925
# 2     Forward                 4.423077
# 3  Goalkeeper                 1.000000

# %% [markdown]
# ### Average fouls per nationality
# we ignore nationalities without any foul information

# %%
query = """SELECT nationality, AVG(fouls_committed) as average_fouls_committed FROM players
                WHERE fouls_committed is not NULL
            GROUP BY nationality ORDER BY average_fouls_committed DESC;
            """
df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df
# Out:
#         nationality  average_fouls_committed
# 0        Mozambique                15.000000
# 1           Austria                 9.500000
# 2          Colombia                 8.200000
# 3   North Macedonia                 8.000000
# 4            Angola                 7.000000
# ..              ...                      ...
# 64           Russia                 1.857143
# 65           Kosovo                 1.000000
# 66          Finland                 1.000000
# 67        Venezuela                 1.000000
# 68          Romania                 1.000000
#
# [69 rows x 2 columns]

# %% [markdown]
# ## Analyse Table countries

# %% [markdown]
# ### Violent Crimes per country per 100 000 citizens

# %%
query = """SELECT country, count_p_100k FROM countries order by count_p_100k desc"""
df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df
# Out:
#                  country  count_p_100k
# 0    U.S. Virgin Islands          49.3
# 1                Jamaica          44.7
# 2                Lesotho          43.6
# 3    Trinidad and Tobago          38.6
# 4            El Salvador          37.2
# ..                   ...           ...
# 190             Holy See           0.0
# 191          Isle of Man           0.0
# 192               Monaco           0.0
# 193         Saint Helena           0.0
# 194           San Marino           0.0
#
# [195 rows x 2 columns]

# %% [markdown]
# ### Analyse GDP Data

# %%
query = """SELECT * from gdp order by gdp_eur DESC LIMIT 10"""
df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df.head(10)
# Out:
#                            _id                          country  \
# 0  (64957bf1e68bcd31216ca85a,)                      (1W, World)
# 1  (64957bf0e68bcd31216ca83b,)                (XD, High income)
# 2  (64957bf1e68bcd31216ca84e,)               (OE, OECD members)
# 3  (64957bf1e68bcd31216ca851,)  (V4, Post-demographic dividend)
# 4  (64957bf0e68bcd31216ca83d,)           (ZT, IDA & IBRD total)
# 5  (64957bf1e68bcd31216ca846,)        (XO, Low & middle income)
# 6  (64957bf1e68bcd31216ca84c,)              (XP, Middle income)
# 7  (64957bf0e68bcd31216ca83c,)                  (XF, IBRD only)
# 8  (64957bf0e68bcd31216ca831,)        (Z4, East Asia & Pacific)
# 9  (64957bf1e68bcd31216ca859,)        (XT, Upper middle income)
#
#   countryiso3code  date  decimal       gdp_eur  \
# 0             WLD  2021        0  8.867009e+13
# 1                  2021        0  5.495954e+13
# 2             OED  2021        0  5.352531e+13
# 3             PST  2021        0  5.049795e+13
# 4             IBT  2021        0  3.496453e+13
# 5             LMY  2021        0  3.341003e+13
# 6             MIC  2021        0  3.292735e+13
# 7             IBD  2021        0  3.253926e+13
# 8             EAS  2021        0  2.839548e+13
# 9                  2021        0  2.489781e+13
#
#                              indicator obs_status         value
# 0  (NY.GDP.MKTP.CD, GDP (current US$))             9.652743e+13
# 1  (NY.GDP.MKTP.CD, GDP (current US$))             5.982967e+13
# 2  (NY.GDP.MKTP.CD, GDP (current US$))             5.826835e+13
# 3  (NY.GDP.MKTP.CD, GDP (current US$))             5.497273e+13
# 4  (NY.GDP.MKTP.CD, GDP (current US$))             3.806285e+13
# 5  (NY.GDP.MKTP.CD, GDP (current US$))             3.637059e+13
# 6  (NY.GDP.MKTP.CD, GDP (current US$))             3.584514e+13
# 7  (NY.GDP.MKTP.CD, GDP (current US$))             3.542267e+13
# 8  (NY.GDP.MKTP.CD, GDP (current US$))             3.091169e+13
# 9  (NY.GDP.MKTP.CD, GDP (current US$))             2.710409e+13

# %% [markdown]
# ### Join table countries and table gdp based on country value

# %%
query = """SELECT c.country, c.count_p_100k, cast((g.gdp_eur / 1000000000) as INT) as billion_gdp_euro
                FROM countries c
                JOIN gdp g ON c.country = TRIM(TRIM('}',SUBSTRING(cast(g.country as String), 5)))
                order by c.count_p_100k desc
            """

df = spark.sql(query)
pandas_df = df.toPandas()
pandas_df.head(100)
# Out:
#                 country  count_p_100k  billion_gdp_euro
# 0               Jamaica          44.7                13
# 1               Lesotho          43.6                 2
# 2   Trinidad and Tobago          38.6                22
# 3           El Salvador          37.2                26
# 4              Honduras          36.3                26
# ..                  ...           ...               ...
# 95         Sierra Leone           1.7                 3
# 96              Finland           1.6               273
# 97                Malta           1.6                15
# 98              Iceland           1.5                23
# 99               Israel           1.5               448
#
# [100 rows x 3 columns]
